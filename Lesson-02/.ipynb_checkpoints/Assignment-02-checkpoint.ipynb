# %% [markdown]
# ## Assignments for Week-02

# %% [markdown]
# In this course, we learnt what's the search problem and what's the machine leanring. In this assignment, we need you do some more practice.

# %% [markdown]
# ### 1. Re-code the house price machine learning

# %%
import random

# %%
from sklearn.datasets import load_boston

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
def draw_rm_and_price():
    plt.scatter(X[:, 5], y)

# %%
data = load_boston()
X, y = data['data'], data['target']

# %%
def price(rm, k, b):
    """f(x) = k * x + b"""
    return k * rm + b

# %%
def loss(y, y_hat): # to evaluate the performance 
    return sum((y_i - y_hat_i)**2 for y_i, y_hat_i in zip(list(y), list(y_hat))) / len(list(y))

# %% [markdown]
# ###### 1. Random Choose Method to get optimal *k* and *b*

# %%
X_rm = X[:, 5]

# %%
def random_optimize(trying_times):
    min_loss = float('inf')
    best_k, best_b = None, None

    for i in range(trying_times):
        k = random.random() * 200 - 100
        b = random.random() * 200 - 100
        price_by_random_k_and_b = [price(r, k, b) for r in X_rm]

        current_loss = loss(y, price_by_random_k_and_b)

        if current_loss < min_loss:
            min_loss = current_loss
            best_k, best_b = k, b
            print('When time is : {}, get best_k: {} best_b: {}, and the loss is: {}'.format(i, best_k, best_b, min_loss))

# %%
random_optimize(2000)
# Out:
# When time is : 0, get best_k: -49.55961324927684 best_b: -25.4980187646332, and the loss is: 130975.62713778012
# When time is : 2, get best_k: -12.787602185918473 best_b: 28.02395536835303, and the loss is: 5885.834242484185
# When time is : 3, get best_k: 3.6946528570520343 best_b: -37.00888326103539, and the loss is: 1377.3056230288557
# When time is : 26, get best_k: -4.250609558318374 best_b: 40.061299879898115, and the loss is: 215.8105301774302
# When time is : 151, get best_k: 14.099097961860664 best_b: -64.20967832542404, and the loss is: 59.38203982589699

# %%
k = 13
b = -58
price_by_random_k_and_b = [price(r, k, b) for r in X_rm]

draw_rm_and_price()
plt.scatter(X_rm, price_by_random_k_and_b)

# %% [markdown]
# ###### 2.Supervised Direction to get optimal *k* and *b*

# %%
def direction_optimize(trying_times):
    min_loss = float('inf')
    best_k = random.random() * 200 - 100
    best_b = random.random() * 200 - 100
    direction = [
        (+1, -1),  # first element: k's change direction, second element: b's change direction
        (+1, +1), 
        (-1, -1), 
        (-1, +1),
    ]
    next_direction = random.choice(direction)
    scalar = 0.1
    for i in range(trying_times):
        k_direction, b_direction = next_direction
        current_k, current_b = best_k + k_direction * scalar, best_b + b_direction * scalar
        price_by_k_and_b = [price(r, current_k, current_b) for r in X_rm]
        current_loss = loss(y, price_by_k_and_b)
        if current_loss < min_loss: # performance became better
            min_loss = current_loss
            best_k, best_b = current_k, current_b
            next_direction = next_direction
            print('When time is : {}, get best_k: {} best_b: {}, and the loss is: {}'.format(i, best_k, best_b, min_loss))
        else:
            next_direction = random.choice(direction)

# %%
direction_optimize(2000)
# Out:
# When time is : 0, get best_k: 69.27832763435626 best_b: -46.16742356063846, and the loss is: 136288.36218287988
# When time is : 2, get best_k: 69.17832763435626 best_b: -46.06742356063846, and the loss is: 135895.15350174505
# When time is : 3, get best_k: 69.07832763435627 best_b: -45.96742356063846, and the loss is: 135502.51322172704
# When time is : 4, get best_k: 68.97832763435628 best_b: -45.86742356063846, and the loss is: 135110.44134282516
# When time is : 5, get best_k: 68.87832763435628 best_b: -45.767423560638456, and the loss is: 134718.93786503992
# When time is : 6, get best_k: 68.77832763435629 best_b: -45.667423560638454, and the loss is: 134328.0027883715
# When time is : 7, get best_k: 68.6783276343563 best_b: -45.56742356063845, and the loss is: 133937.6361128192
# When time is : 8, get best_k: 68.5783276343563 best_b: -45.46742356063845, and the loss is: 133547.83783838342
# When time is : 9, get best_k: 68.4783276343563 best_b: -45.36742356063845, and the loss is: 133158.60796506415
# When time is : 10, get best_k: 68.37832763435631 best_b: -45.26742356063845, and the loss is: 132769.94649286135
# When time is : 11, get best_k: 68.27832763435632 best_b: -45.16742356063845, and the loss is: 132381.85342177504
# When time is : 12, get best_k: 68.17832763435632 best_b: -45.067423560638446, and the loss is: 131994.3287518052
# When time is : 13, get best_k: 68.07832763435633 best_b: -44.967423560638444, and the loss is: 131607.37248295205
# When time is : 14, get best_k: 67.97832763435633 best_b: -44.86742356063844, and the loss is: 131220.9846152151
# When time is : 15, get best_k: 67.87832763435634 best_b: -44.76742356063844, and the loss is: 130835.1651485948
# When time is : 16, get best_k: 67.77832763435634 best_b: -44.66742356063844, and the loss is: 130449.91408309084
# When time is : 17, get best_k: 67.67832763435635 best_b: -44.56742356063844, and the loss is: 130065.23141870348
# When time is : 18, get best_k: 67.57832763435636 best_b: -44.46742356063844, and the loss is: 129681.11715543251
# When time is : 19, get best_k: 67.47832763435636 best_b: -44.367423560638436, and the loss is: 129297.57129327803
# When time is : 20, get best_k: 67.37832763435637 best_b: -44.267423560638434, and the loss is: 128914.59383224016
# When time is : 21, get best_k: 67.27832763435637 best_b: -44.16742356063843, and the loss is: 128532.18477231867
# When time is : 22, get best_k: 67.17832763435638 best_b: -44.06742356063843, and the loss is: 128150.34411351365
# When time is : 23, get best_k: 67.07832763435638 best_b: -43.96742356063843, and the loss is: 127769.0718558251
# When time is : 24, get best_k: 66.97832763435639 best_b: -43.86742356063843, and the loss is: 127388.36799925315
# When time is : 25, get best_k: 66.8783276343564 best_b: -43.76742356063843, and the loss is: 127008.23254379747
# When time is : 26, get best_k: 66.7783276343564 best_b: -43.667423560638426, and the loss is: 126628.66548945851
# When time is : 27, get best_k: 66.6783276343564 best_b: -43.567423560638424, and the loss is: 126249.66683623592
# When time is : 28, get best_k: 66.57832763435641 best_b: -43.46742356063842, and the loss is: 125871.23658412983
# When time is : 29, get best_k: 66.47832763435642 best_b: -43.36742356063842, and the loss is: 125493.3747331402
# When time is : 30, get best_k: 66.37832763435642 best_b: -43.26742356063842, and the loss is: 125116.08128326695
# When time is : 31, get best_k: 66.27832763435643 best_b: -43.16742356063842, and the loss is: 124739.35623451036
# When time is : 32, get best_k: 66.17832763435644 best_b: -43.06742356063842, and the loss is: 124363.19958687008
# When time is : 33, get best_k: 66.07832763435644 best_b: -42.967423560638416, and the loss is: 123987.61134034647
# When time is : 34, get best_k: 65.97832763435645 best_b: -42.867423560638414, and the loss is: 123612.5914949392
# When time is : 35, get best_k: 65.87832763435645 best_b: -42.76742356063841, and the loss is: 123238.14005064857
# When time is : 36, get best_k: 65.77832763435646 best_b: -42.66742356063841, and the loss is: 122864.25700747427
# When time is : 37, get best_k: 65.67832763435646 best_b: -42.56742356063841, and the loss is: 122490.94236541654
# When time is : 38, get best_k: 65.57832763435647 best_b: -42.46742356063841, and the loss is: 122118.19612447527
# When time is : 39, get best_k: 65.47832763435648 best_b: -42.36742356063841, and the loss is: 121746.01828465026
# When time is : 40, get best_k: 65.37832763435648 best_b: -42.267423560638406, and the loss is: 121374.40884594203
# When time is : 41, get best_k: 65.27832763435649 best_b: -42.167423560638404, and the loss is: 121003.36780835032
# When time is : 42, get best_k: 65.17832763435649 best_b: -42.0674235606384, and the loss is: 120632.8951718749
# When time is : 43, get best_k: 65.0783276343565 best_b: -41.9674235606384, and the loss is: 120262.99093651609
# When time is : 44, get best_k: 64.9783276343565 best_b: -41.8674235606384, and the loss is: 119893.65510227374
# When time is : 45, get best_k: 64.87832763435651 best_b: -41.7674235606384, and the loss is: 119524.88766914779
# When time is : 46, get best_k: 64.77832763435651 best_b: -41.6674235606384, and the loss is: 119156.6886371383
# When time is : 47, get best_k: 64.67832763435652 best_b: -41.567423560638396, and the loss is: 118789.05800624542
# When time is : 48, get best_k: 64.57832763435653 best_b: -41.467423560638395, and the loss is: 118421.99577646899
# When time is : 49, get best_k: 64.47832763435653 best_b: -41.36742356063839, and the loss is: 118055.50194780901
# When time is : 50, get best_k: 64.37832763435654 best_b: -41.26742356063839, and the loss is: 117689.57652026553
# When time is : 51, get best_k: 64.27832763435654 best_b: -41.16742356063839, and the loss is: 117324.21949383846
# When time is : 52, get best_k: 64.17832763435655 best_b: -41.06742356063839, and the loss is: 116959.43086852782
# When time is : 53, get best_k: 64.07832763435655 best_b: -40.96742356063839, and the loss is: 116595.21064433386
# When time is : 54, get best_k: 63.97832763435655 best_b: -40.867423560638386, and the loss is: 116231.5588212564
# When time is : 55, get best_k: 63.87832763435655 best_b: -40.767423560638385, and the loss is: 115868.4753992952
# When time is : 56, get best_k: 63.77832763435655 best_b: -40.66742356063838, and the loss is: 115505.96037845062
# When time is : 57, get best_k: 63.67832763435655 best_b: -40.56742356063838, and the loss is: 115144.01375872246
# When time is : 58, get best_k: 63.57832763435655 best_b: -40.46742356063838, and the loss is: 114782.63554011089
# When time is : 59, get best_k: 63.478327634356546 best_b: -40.36742356063838, and the loss is: 114421.8257226155
# When time is : 60, get best_k: 63.378327634356545 best_b: -40.26742356063838, and the loss is: 114061.58430623681
# When time is : 61, get best_k: 63.27832763435654 best_b: -40.167423560638376, and the loss is: 113701.91129097457
# When time is : 62, get best_k: 63.17832763435654 best_b: -40.067423560638375, and the loss is: 113342.80667682893
# When time is : 63, get best_k: 63.07832763435654 best_b: -39.96742356063837, and the loss is: 112984.2704637995
# When time is : 64, get best_k: 62.97832763435654 best_b: -39.86742356063837, and the loss is: 112626.30265188677
# When time is : 65, get best_k: 62.87832763435654 best_b: -39.76742356063837, and the loss is: 112268.90324109042
# When time is : 66, get best_k: 62.778327634356536 best_b: -39.66742356063837, and the loss is: 111912.07223141073
# When time is : 67, get best_k: 62.678327634356535 best_b: -39.56742356063837, and the loss is: 111555.80962284739
# When time is : 68, get best_k: 62.57832763435653 best_b: -39.467423560638366, and the loss is: 111200.11541540058
# When time is : 69, get best_k: 62.47832763435653 best_b: -39.367423560638365, and the loss is: 110844.98960907027
# When time is : 70, get best_k: 62.37832763435653 best_b: -39.26742356063836, and the loss is: 110490.43220385633
# When time is : 71, get best_k: 62.27832763435653 best_b: -39.16742356063836, and the loss is: 110136.44319975885
# When time is : 72, get best_k: 62.17832763435653 best_b: -39.06742356063836, and the loss is: 109783.02259677798
# When time is : 73, get best_k: 62.078327634356526 best_b: -38.96742356063836, and the loss is: 109430.17039491357
# When time is : 74, get best_k: 61.978327634356525 best_b: -38.86742356063836, and the loss is: 109077.88659416554
# When time is : 75, get best_k: 61.87832763435652 best_b: -38.767423560638356, and the loss is: 108726.17119453415
# When time is : 76, get best_k: 61.77832763435652 best_b: -38.667423560638355, and the loss is: 108375.02419601909
# When time is : 77, get best_k: 61.67832763435652 best_b: -38.56742356063835, and the loss is: 108024.44559862057
# When time is : 78, get best_k: 61.57832763435652 best_b: -38.46742356063835, and the loss is: 107674.43540233858
# When time is : 79, get best_k: 61.47832763435652 best_b: -38.36742356063835, and the loss is: 107324.99360717303
# When time is : 80, get best_k: 61.378327634356516 best_b: -38.26742356063835, and the loss is: 106976.12021312388
# When time is : 81, get best_k: 61.278327634356515 best_b: -38.16742356063835, and the loss is: 106627.8152201913
# When time is : 82, get best_k: 61.17832763435651 best_b: -38.067423560638346, and the loss is: 106280.07862837527
# When time is : 83, get best_k: 61.07832763435651 best_b: -37.967423560638345, and the loss is: 105932.91043767564
# When time is : 84, get best_k: 60.97832763435651 best_b: -37.86742356063834, and the loss is: 105586.31064809248
# When time is : 85, get best_k: 60.87832763435651 best_b: -37.76742356063834, and the loss is: 105240.27925962585
# When time is : 86, get best_k: 60.77832763435651 best_b: -37.66742356063834, and the loss is: 104894.81627227576
# When time is : 87, get best_k: 60.678327634356506 best_b: -37.56742356063834, and the loss is: 104549.92168604209
# When time is : 88, get best_k: 60.578327634356505 best_b: -37.46742356063834, and the loss is: 104205.59550092483
# When time is : 89, get best_k: 60.4783276343565 best_b: -37.367423560638336, and the loss is: 103861.83771692424
# When time is : 90, get best_k: 60.3783276343565 best_b: -37.267423560638335, and the loss is: 103518.64833403984
# When time is : 91, get best_k: 60.2783276343565 best_b: -37.16742356063833, and the loss is: 103176.02735227214
# When time is : 92, get best_k: 60.1783276343565 best_b: -37.06742356063833, and the loss is: 102833.97477162095
# When time is : 93, get best_k: 60.0783276343565 best_b: -36.96742356063833, and the loss is: 102492.49059208603
# When time is : 94, get best_k: 59.978327634356496 best_b: -36.86742356063833, and the loss is: 102151.57481366771
# When time is : 95, get best_k: 59.878327634356495 best_b: -36.76742356063833, and the loss is: 101811.22743636597
# When time is : 96, get best_k: 59.77832763435649 best_b: -36.667423560638326, and the loss is: 101471.44846018056
# When time is : 97, get best_k: 59.67832763435649 best_b: -36.567423560638325, and the loss is: 101132.23788511168
# When time is : 98, get best_k: 59.57832763435649 best_b: -36.46742356063832, and the loss is: 100793.5957111592
# When time is : 99, get best_k: 59.47832763435649 best_b: -36.36742356063832, and the loss is: 100455.52193832329
# When time is : 100, get best_k: 59.37832763435649 best_b: -36.26742356063832, and the loss is: 100118.016566604
# When time is : 101, get best_k: 59.278327634356486 best_b: -36.16742356063832, and the loss is: 99781.07959600113
# When time is : 102, get best_k: 59.178327634356485 best_b: -36.06742356063832, and the loss is: 99444.7110265146
# When time is : 103, get best_k: 59.078327634356484 best_b: -35.967423560638316, and the loss is: 99108.91085814465
# When time is : 104, get best_k: 58.97832763435648 best_b: -35.867423560638315, and the loss is: 98773.67909089122
# When time is : 105, get best_k: 58.87832763435648 best_b: -35.76742356063831, and the loss is: 98439.01572475422
# When time is : 106, get best_k: 58.77832763435648 best_b: -35.66742356063831, and the loss is: 98104.92075973364
# When time is : 107, get best_k: 58.67832763435648 best_b: -35.56742356063831, and the loss is: 97771.39419582959
# When time is : 108, get best_k: 58.57832763435648 best_b: -35.46742356063831, and the loss is: 97438.43603304202
# When time is : 109, get best_k: 58.478327634356475 best_b: -35.36742356063831, and the loss is: 97106.04627137093
# When time is : 110, get best_k: 58.378327634356474 best_b: -35.267423560638306, and the loss is: 96774.22491081648
# When time is : 111, get best_k: 58.27832763435647 best_b: -35.167423560638305, and the loss is: 96442.97195137835
# When time is : 112, get best_k: 58.17832763435647 best_b: -35.067423560638304, and the loss is: 96112.28739305654
# When time is : 113, get best_k: 58.07832763435647 best_b: -34.9674235606383, and the loss is: 95782.1712358516
# When time is : 114, get best_k: 57.97832763435647 best_b: -34.8674235606383, and the loss is: 95452.62347976275
# When time is : 115, get best_k: 57.87832763435647 best_b: -34.7674235606383, and the loss is: 95123.64412479066
# When time is : 116, get best_k: 57.778327634356465 best_b: -34.6674235606383, and the loss is: 94795.233170935
# When time is : 117, get best_k: 57.678327634356464 best_b: -34.5674235606383, and the loss is: 94467.39061819573
# When time is : 118, get best_k: 57.57832763435646 best_b: -34.467423560638295, and the loss is: 94140.116466573
# When time is : 119, get best_k: 57.47832763435646 best_b: -34.367423560638294, and the loss is: 93813.41071606673
# When time is : 120, get best_k: 57.37832763435646 best_b: -34.26742356063829, and the loss is: 93487.27336667695
# When time is : 121, get best_k: 57.27832763435646 best_b: -34.16742356063829, and the loss is: 93161.70441840365
# When time is : 122, get best_k: 57.17832763435646 best_b: -34.06742356063829, and the loss is: 92836.70387124675
# When time is : 123, get best_k: 57.078327634356455 best_b: -33.96742356063829, and the loss is: 92512.27172520653
# When time is : 124, get best_k: 56.978327634356454 best_b: -33.86742356063829, and the loss is: 92188.40798028265
# When time is : 125, get best_k: 56.87832763435645 best_b: -33.767423560638285, and the loss is: 91865.11263647531
# When time is : 126, get best_k: 56.77832763435645 best_b: -33.667423560638284, and the loss is: 91542.38569378444
# When time is : 127, get best_k: 56.67832763435645 best_b: -33.56742356063828, and the loss is: 91220.22715221002
# When time is : 128, get best_k: 56.57832763435645 best_b: -33.46742356063828, and the loss is: 90898.6370117522
# When time is : 129, get best_k: 56.47832763435645 best_b: -33.36742356063828, and the loss is: 90577.61527241067
# When time is : 130, get best_k: 56.378327634356445 best_b: -33.26742356063828, and the loss is: 90257.16193418582
# When time is : 131, get best_k: 56.278327634356444 best_b: -33.16742356063828, and the loss is: 89937.2769970772
# When time is : 132, get best_k: 56.17832763435644 best_b: -33.067423560638275, and the loss is: 89617.96046108537
# When time is : 133, get best_k: 56.07832763435644 best_b: -32.967423560638274, and the loss is: 89299.21232620979
# When time is : 134, get best_k: 55.97832763435644 best_b: -32.86742356063827, and the loss is: 88981.03259245078
# When time is : 135, get best_k: 55.87832763435644 best_b: -32.76742356063827, and the loss is: 88663.42125980821
# When time is : 136, get best_k: 55.77832763435644 best_b: -32.66742356063827, and the loss is: 88346.37832828221
# When time is : 137, get best_k: 55.678327634356435 best_b: -32.56742356063827, and the loss is: 88029.90379787264
# When time is : 138, get best_k: 55.578327634356434 best_b: -32.46742356063827, and the loss is: 87713.99766857963
# When time is : 139, get best_k: 55.47832763435643 best_b: -32.367423560638265, and the loss is: 87398.65994040288
# When time is : 140, get best_k: 55.37832763435643 best_b: -32.267423560638264, and the loss is: 87083.89061334272
# When time is : 141, get best_k: 55.27832763435643 best_b: -32.16742356063826, and the loss is: 86769.6896873991
# When time is : 142, get best_k: 55.17832763435643 best_b: -32.06742356063826, and the loss is: 86456.05716257195
# When time is : 143, get best_k: 55.07832763435643 best_b: -31.96742356063826, and the loss is: 86142.99303886123
# When time is : 144, get best_k: 54.978327634356425 best_b: -31.867423560638258, and the loss is: 85830.49731626724
# When time is : 145, get best_k: 54.878327634356424 best_b: -31.767423560638257, and the loss is: 85518.56999478933
# When time is : 146, get best_k: 54.77832763435642 best_b: -31.667423560638255, and the loss is: 85207.2110744282
# When time is : 147, get best_k: 54.67832763435642 best_b: -31.567423560638254, and the loss is: 84896.42055518334
# When time is : 148, get best_k: 54.57832763435642 best_b: -31.467423560638252, and the loss is: 84586.19843705518
# When time is : 149, get best_k: 54.47832763435642 best_b: -31.36742356063825, and the loss is: 84276.54472004325
# When time is : 150, get best_k: 54.37832763435642 best_b: -31.26742356063825, and the loss is: 83967.459404148
# When time is : 151, get best_k: 54.278327634356415 best_b: -31.167423560638248, and the loss is: 83658.94248936926
# When time is : 152, get best_k: 54.178327634356414 best_b: -31.067423560638247, and the loss is: 83350.99397570691
# When time is : 153, get best_k: 54.07832763435641 best_b: -30.967423560638245, and the loss is: 83043.613863161
# When time is : 154, get best_k: 53.97832763435641 best_b: -30.867423560638244, and the loss is: 82736.80215173155
# When time is : 155, get best_k: 53.87832763435641 best_b: -30.767423560638242, and the loss is: 82430.55884141884
# When time is : 156, get best_k: 53.77832763435641 best_b: -30.66742356063824, and the loss is: 82124.88393222229
# When time is : 157, get best_k: 53.67832763435641 best_b: -30.56742356063824, and the loss is: 81819.77742414243
# When time is : 158, get best_k: 53.578327634356405 best_b: -30.467423560638238, and the loss is: 81515.239317179
# When time is : 159, get best_k: 53.478327634356404 best_b: -30.367423560638237, and the loss is: 81211.26961133198
# When time is : 160, get best_k: 53.3783276343564 best_b: -30.267423560638235, and the loss is: 80907.86830660154
# When time is : 161, get best_k: 53.2783276343564 best_b: -30.167423560638234, and the loss is: 80605.03540298753
# When time is : 162, get best_k: 53.1783276343564 best_b: -30.067423560638233, and the loss is: 80302.77090048995
# When time is : 163, get best_k: 53.0783276343564 best_b: -29.96742356063823, and the loss is: 80001.07479910892
# When time is : 164, get best_k: 52.9783276343564 best_b: -29.86742356063823, and the loss is: 79699.94709884444
# When time is : 165, get best_k: 52.878327634356395 best_b: -29.76742356063823, and the loss is: 79399.38779969634
# When time is : 166, get best_k: 52.778327634356394 best_b: -29.667423560638227, and the loss is: 79099.39690166475
# When time is : 167, get best_k: 52.67832763435639 best_b: -29.567423560638225, and the loss is: 78799.97440474972
# When time is : 168, get best_k: 52.57832763435639 best_b: -29.467423560638224, and the loss is: 78501.12030895102
# When time is : 169, get best_k: 52.47832763435639 best_b: -29.367423560638223, and the loss is: 78202.83461426897
# When time is : 170, get best_k: 52.37832763435639 best_b: -29.26742356063822, and the loss is: 77905.1173207033
# When time is : 171, get best_k: 52.27832763435639 best_b: -29.16742356063822, and the loss is: 77607.96842825403
# When time is : 172, get best_k: 52.178327634356386 best_b: -29.06742356063822, and the loss is: 77311.38793692127
# When time is : 173, get best_k: 52.078327634356384 best_b: -28.967423560638217, and the loss is: 77015.37584670511
# When time is : 174, get best_k: 51.97832763435638 best_b: -28.867423560638215, and the loss is: 76719.93215760546
# When time is : 175, get best_k: 51.87832763435638 best_b: -28.767423560638214, and the loss is: 76425.05686962212
# When time is : 176, get best_k: 51.77832763435638 best_b: -28.667423560638213, and the loss is: 76130.74998275541
# When time is : 177, get best_k: 51.67832763435638 best_b: -28.56742356063821, and the loss is: 75837.01149700512
# When time is : 178, get best_k: 51.57832763435638 best_b: -28.46742356063821, and the loss is: 75543.84141237129
# When time is : 179, get best_k: 51.478327634356376 best_b: -28.36742356063821, and the loss is: 75251.2397288539
# When time is : 180, get best_k: 51.378327634356374 best_b: -28.267423560638207, and the loss is: 74959.20644645316
# When time is : 181, get best_k: 51.27832763435637 best_b: -28.167423560638206, and the loss is: 74667.74156516879
# When time is : 182, get best_k: 51.17832763435637 best_b: -28.067423560638204, and the loss is: 74376.84508500092
# When time is : 183, get best_k: 51.07832763435637 best_b: -27.967423560638203, and the loss is: 74086.51700594951
# When time is : 184, get best_k: 50.97832763435637 best_b: -27.8674235606382, and the loss is: 73796.75732801454
# When time is : 185, get best_k: 50.87832763435637 best_b: -27.7674235606382, and the loss is: 73507.56605119626
# When time is : 186, get best_k: 50.778327634356366 best_b: -27.6674235606382, and the loss is: 73218.94317549418
# When time is : 187, get best_k: 50.678327634356364 best_b: -27.567423560638197, and the loss is: 72930.88870090875
# When time is : 188, get best_k: 50.57832763435636 best_b: -27.467423560638196, and the loss is: 72643.40262743979
# When time is : 189, get best_k: 50.47832763435636 best_b: -27.367423560638194, and the loss is: 72356.4849550873
# When time is : 190, get best_k: 50.37832763435636 best_b: -27.267423560638193, and the loss is: 72070.13568385139
# When time is : 191, get best_k: 50.27832763435636 best_b: -27.16742356063819, and the loss is: 71784.35481373165
# When time is : 192, get best_k: 50.17832763435636 best_b: -27.06742356063819, and the loss is: 71499.14234472875
# When time is : 193, get best_k: 50.078327634356356 best_b: -26.96742356063819, and the loss is: 71214.49827684207
# When time is : 194, get best_k: 49.978327634356354 best_b: -26.867423560638187, and the loss is: 70930.4226100721
# When time is : 195, get best_k: 49.87832763435635 best_b: -26.767423560638186, and the loss is: 70646.91534441849
# When time is : 196, get best_k: 49.77832763435635 best_b: -26.667423560638184, and the loss is: 70363.97647988124
# When time is : 197, get best_k: 49.67832763435635 best_b: -26.567423560638183, and the loss is: 70081.60601646072
# When time is : 198, get best_k: 49.57832763435635 best_b: -26.46742356063818, and the loss is: 69799.80395415658
# When time is : 199, get best_k: 49.47832763435635 best_b: -26.36742356063818, and the loss is: 69518.5702929688
# When time is : 200, get best_k: 49.378327634356346 best_b: -26.26742356063818, and the loss is: 69237.90503289764
# When time is : 201, get best_k: 49.278327634356344 best_b: -26.167423560638177, and the loss is: 68957.80817394293
# When time is : 202, get best_k: 49.17832763435634 best_b: -26.067423560638176, and the loss is: 68678.27971610463
# When time is : 203, get best_k: 49.07832763435634 best_b: -25.967423560638174, and the loss is: 68399.3196593829
# When time is : 204, get best_k: 48.97832763435634 best_b: -25.867423560638173, and the loss is: 68120.92800377769
# When time is : 205, get best_k: 48.87832763435634 best_b: -25.76742356063817, and the loss is: 67843.1047492889
# When time is : 206, get best_k: 48.77832763435634 best_b: -25.66742356063817, and the loss is: 67565.84989591653
# When time is : 207, get best_k: 48.678327634356336 best_b: -25.56742356063817, and the loss is: 67289.16344366077
# When time is : 208, get best_k: 48.578327634356334 best_b: -25.467423560638167, and the loss is: 67013.04539252151
# When time is : 209, get best_k: 48.47832763435633 best_b: -25.367423560638166, and the loss is: 66737.49574249864
# When time is : 210, get best_k: 48.37832763435633 best_b: -25.267423560638164, and the loss is: 66462.51449359219
# When time is : 211, get best_k: 48.27832763435633 best_b: -25.167423560638163, and the loss is: 66188.1016458023
# When time is : 212, get best_k: 48.17832763435633 best_b: -25.06742356063816, and the loss is: 65914.25719912899
# When time is : 213, get best_k: 48.07832763435633 best_b: -24.96742356063816, and the loss is: 65640.98115357204
# When time is : 214, get best_k: 47.978327634356326 best_b: -24.86742356063816, and the loss is: 65368.27350913156
# When time is : 215, get best_k: 47.878327634356324 best_b: -24.767423560638157, and the loss is: 65096.13426580761
# When time is : 216, get best_k: 47.77832763435632 best_b: -24.667423560638156, and the loss is: 64824.5634236001
# When time is : 217, get best_k: 47.67832763435632 best_b: -24.567423560638154, and the loss is: 64553.56098250921
# When time is : 218, get best_k: 47.57832763435632 best_b: -24.467423560638153, and the loss is: 64283.12694253459
# When time is : 219, get best_k: 47.47832763435632 best_b: -24.36742356063815, and the loss is: 64013.26130367656
# When time is : 220, get best_k: 47.37832763435632 best_b: -24.26742356063815, and the loss is: 63743.96406593504
# When time is : 221, get best_k: 47.278327634356316 best_b: -24.16742356063815, and the loss is: 63475.23522930997
# When time is : 222, get best_k: 47.178327634356314 best_b: -24.067423560638147, and the loss is: 63207.07479380142
# When time is : 223, get best_k: 47.07832763435631 best_b: -23.967423560638146, and the loss is: 62939.48275940932
# When time is : 224, get best_k: 46.97832763435631 best_b: -23.867423560638144, and the loss is: 62672.45912613369
# When time is : 225, get best_k: 46.87832763435631 best_b: -23.767423560638143, and the loss is: 62406.00389397459
# When time is : 226, get best_k: 46.77832763435631 best_b: -23.66742356063814, and the loss is: 62140.117062931866
# When time is : 227, get best_k: 46.67832763435631 best_b: -23.56742356063814, and the loss is: 61874.7986330057
# When time is : 228, get best_k: 46.578327634356306 best_b: -23.46742356063814, and the loss is: 61610.04860419605
# When time is : 229, get best_k: 46.478327634356305 best_b: -23.367423560638137, and the loss is: 61345.86697650283
# When time is : 230, get best_k: 46.3783276343563 best_b: -23.267423560638136, and the loss is: 61082.253749926094
# When time is : 231, get best_k: 46.2783276343563 best_b: -23.167423560638134, and the loss is: 60819.2089244658
# When time is : 232, get best_k: 46.1783276343563 best_b: -23.067423560638133, and the loss is: 60556.73250012213
# When time is : 233, get best_k: 46.0783276343563 best_b: -22.96742356063813, and the loss is: 60294.82447689477
# When time is : 234, get best_k: 45.9783276343563 best_b: -22.86742356063813, and the loss is: 60033.48485478401
# When time is : 235, get best_k: 45.878327634356296 best_b: -22.76742356063813, and the loss is: 59772.713633789725
# When time is : 236, get best_k: 45.778327634356295 best_b: -22.667423560638127, and the loss is: 59512.51081391181
# When time is : 237, get best_k: 45.67832763435629 best_b: -22.567423560638126, and the loss is: 59252.87639515049
# When time is : 238, get best_k: 45.57832763435629 best_b: -22.467423560638125, and the loss is: 58993.81037750568
# When time is : 239, get best_k: 45.47832763435629 best_b: -22.367423560638123, and the loss is: 58735.31276097725
# When time is : 240, get best_k: 45.37832763435629 best_b: -22.26742356063812, and the loss is: 58477.38354556534
# When time is : 241, get best_k: 45.27832763435629 best_b: -22.16742356063812, and the loss is: 58220.02273126995
# When time is : 242, get best_k: 45.178327634356286 best_b: -22.06742356063812, and the loss is: 57963.230318090966
# When time is : 243, get best_k: 45.078327634356285 best_b: -21.967423560638117, and the loss is: 57707.006306028554
# When time is : 244, get best_k: 44.97832763435628 best_b: -21.867423560638116, and the loss is: 57451.350695082525
# When time is : 245, get best_k: 44.87832763435628 best_b: -21.767423560638115, and the loss is: 57196.263485253054
# When time is : 246, get best_k: 44.77832763435628 best_b: -21.667423560638113, and the loss is: 56941.74467654
# When time is : 247, get best_k: 44.67832763435628 best_b: -21.56742356063811, and the loss is: 56687.7942689435
# When time is : 248, get best_k: 44.57832763435628 best_b: -21.46742356063811, and the loss is: 56434.41226246343
# When time is : 249, get best_k: 44.478327634356276 best_b: -21.36742356063811, and the loss is: 56181.59865709998
# When time is : 250, get best_k: 44.378327634356275 best_b: -21.267423560638107, and the loss is: 55929.35345285282
# When time is : 251, get best_k: 44.27832763435627 best_b: -21.167423560638106, and the loss is: 55677.67664972218
# When time is : 252, get best_k: 44.17832763435627 best_b: -21.067423560638105, and the loss is: 55426.5682477081
# When time is : 253, get best_k: 44.07832763435627 best_b: -20.967423560638103, and the loss is: 55176.02824681047
# When time is : 254, get best_k: 43.97832763435627 best_b: -20.8674235606381, and the loss is: 54926.05664702932
# When time is : 255, get best_k: 43.87832763435627 best_b: -20.7674235606381, and the loss is: 54676.653448364654
# When time is : 256, get best_k: 43.778327634356266 best_b: -20.6674235606381, and the loss is: 54427.818650816494
# When time is : 257, get best_k: 43.678327634356265 best_b: -20.567423560638098, and the loss is: 54179.55225438474
# When time is : 258, get best_k: 43.57832763435626 best_b: -20.467423560638096, and the loss is: 53931.8542590695
# When time is : 259, get best_k: 43.47832763435626 best_b: -20.367423560638095, and the loss is: 53684.724664870715
# When time is : 260, get best_k: 43.37832763435626 best_b: -20.267423560638093, and the loss is: 53438.163471788524
# When time is : 261, get best_k: 43.27832763435626 best_b: -20.167423560638092, and the loss is: 53192.17067982274
# When time is : 262, get best_k: 43.17832763435626 best_b: -20.06742356063809, and the loss is: 52946.74628897351
# When time is : 263, get best_k: 43.078327634356256 best_b: -19.96742356063809, and the loss is: 52701.89029924061
# When time is : 264, get best_k: 42.978327634356255 best_b: -19.867423560638088, and the loss is: 52457.60271062428
# When time is : 265, get best_k: 42.87832763435625 best_b: -19.767423560638086, and the loss is: 52213.88352312448
# When time is : 266, get best_k: 42.77832763435625 best_b: -19.667423560638085, and the loss is: 51970.73273674111
# When time is : 267, get best_k: 42.67832763435625 best_b: -19.567423560638083, and the loss is: 51728.15035147423
# When time is : 268, get best_k: 42.57832763435625 best_b: -19.467423560638082, and the loss is: 51486.136367323794
# When time is : 269, get best_k: 42.47832763435625 best_b: -19.36742356063808, and the loss is: 51244.69078428991
# When time is : 270, get best_k: 42.378327634356246 best_b: -19.26742356063808, and the loss is: 51003.81360237245
# When time is : 271, get best_k: 42.278327634356245 best_b: -19.167423560638078, and the loss is: 50763.50482157154
# When time is : 272, get best_k: 42.17832763435624 best_b: -19.067423560638076, and the loss is: 50523.76444188698
# When time is : 273, get best_k: 42.07832763435624 best_b: -18.967423560638075, and the loss is: 50284.592463319044
# When time is : 274, get best_k: 41.97832763435624 best_b: -18.867423560638073, and the loss is: 50045.98888586752
# When time is : 275, get best_k: 41.87832763435624 best_b: -18.767423560638072, and the loss is: 49807.95370953254
# When time is : 276, get best_k: 41.77832763435624 best_b: -18.66742356063807, and the loss is: 49570.48693431397
# When time is : 277, get best_k: 41.678327634356236 best_b: -18.56742356063807, and the loss is: 49333.5885602119
# When time is : 278, get best_k: 41.578327634356235 best_b: -18.467423560638068, and the loss is: 49097.2585872263
# When time is : 279, get best_k: 41.47832763435623 best_b: -18.367423560638066, and the loss is: 48861.49701535718
# When time is : 280, get best_k: 41.37832763435623 best_b: -18.267423560638065, and the loss is: 48626.30384460464
# When time is : 281, get best_k: 41.27832763435623 best_b: -18.167423560638063, and the loss is: 48391.67907496852
# When time is : 282, get best_k: 41.17832763435623 best_b: -18.067423560638062, and the loss is: 48157.62270644879
# When time is : 283, get best_k: 41.07832763435623 best_b: -17.96742356063806, and the loss is: 47924.134739045636
# When time is : 284, get best_k: 40.978327634356226 best_b: -17.86742356063806, and the loss is: 47691.21517275898
# When time is : 285, get best_k: 40.878327634356225 best_b: -17.767423560638058, and the loss is: 47458.86400758876
# When time is : 286, get best_k: 40.77832763435622 best_b: -17.667423560638056, and the loss is: 47227.08124353504
# When time is : 287, get best_k: 40.67832763435622 best_b: -17.567423560638055, and the loss is: 46995.86688059772
# When time is : 288, get best_k: 40.57832763435622 best_b: -17.467423560638053, and the loss is: 46765.22091877709
# When time is : 289, get best_k: 40.47832763435622 best_b: -17.367423560638052, and the loss is: 46535.143358072724
# When time is : 290, get best_k: 40.37832763435622 best_b: -17.26742356063805, and the loss is: 46305.63419848498
# When time is : 291, get best_k: 40.278327634356216 best_b: -17.16742356063805, and the loss is: 46076.69344001364
# When time is : 292, get best_k: 40.178327634356215 best_b: -17.067423560638048, and the loss is: 45848.32108265888
# When time is : 293, get best_k: 40.078327634356214 best_b: -16.967423560638046, and the loss is: 45620.51712642048
# When time is : 294, get best_k: 39.97832763435621 best_b: -16.867423560638045, and the loss is: 45393.2815712986
# When time is : 295, get best_k: 39.87832763435621 best_b: -16.767423560638044, and the loss is: 45166.61441729324
# When time is : 296, get best_k: 39.77832763435621 best_b: -16.667423560638042, and the loss is: 44940.51566440432
# When time is : 297, get best_k: 39.67832763435621 best_b: -16.56742356063804, and the loss is: 44714.985312631936
# When time is : 298, get best_k: 39.57832763435621 best_b: -16.46742356063804, and the loss is: 44490.02336197598
# When time is : 299, get best_k: 39.478327634356205 best_b: -16.367423560638038, and the loss is: 44265.629812436564
# When time is : 300, get best_k: 39.378327634356204 best_b: -16.267423560638036, and the loss is: 44041.804664013616
# When time is : 301, get best_k: 39.2783276343562 best_b: -16.167423560638035, and the loss is: 43818.54791670705
# When time is : 302, get best_k: 39.1783276343562 best_b: -16.067423560638034, and the loss is: 43595.859570517074
# When time is : 303, get best_k: 39.0783276343562 best_b: -15.967423560638034, and the loss is: 43373.7396254435
# When time is : 304, get best_k: 38.9783276343562 best_b: -15.867423560638034, and the loss is: 43152.18808148648
# When time is : 305, get best_k: 38.8783276343562 best_b: -15.767423560638035, and the loss is: 42931.204938645926
# When time is : 306, get best_k: 38.778327634356195 best_b: -15.667423560638035, and the loss is: 42710.790196921866
# When time is : 307, get best_k: 38.678327634356194 best_b: -15.567423560638035, and the loss is: 42490.94385631427
# When time is : 308, get best_k: 38.57832763435619 best_b: -15.467423560638036, and the loss is: 42271.66591682313
# When time is : 309, get best_k: 38.47832763435619 best_b: -15.367423560638036, and the loss is: 42052.95637844852
# When time is : 310, get best_k: 38.37832763435619 best_b: -15.267423560638036, and the loss is: 41834.81524119038
# When time is : 311, get best_k: 38.27832763435619 best_b: -15.167423560638037, and the loss is: 41617.24250504875
# When time is : 312, get best_k: 38.17832763435619 best_b: -15.067423560638037, and the loss is: 41400.23817002351
# When time is : 313, get best_k: 38.078327634356185 best_b: -14.967423560638037, and the loss is: 41183.80223611489
# When time is : 314, get best_k: 37.978327634356184 best_b: -14.867423560638038, and the loss is: 40967.934703322615
# When time is : 315, get best_k: 37.87832763435618 best_b: -14.767423560638038, and the loss is: 40752.635571646875
# When time is : 316, get best_k: 37.77832763435618 best_b: -14.667423560638039, and the loss is: 40537.90484108762
# When time is : 317, get best_k: 37.67832763435618 best_b: -14.567423560638039, and the loss is: 40323.74251164479
# When time is : 318, get best_k: 37.57832763435618 best_b: -14.46742356063804, and the loss is: 40110.148583318514
# When time is : 319, get best_k: 37.47832763435618 best_b: -14.36742356063804, and the loss is: 39897.12305610875
# When time is : 320, get best_k: 37.378327634356175 best_b: -14.26742356063804, and the loss is: 39684.66593001539
# When time is : 321, get best_k: 37.278327634356174 best_b: -14.16742356063804, and the loss is: 39472.777205038576
# When time is : 322, get best_k: 37.17832763435617 best_b: -14.06742356063804, and the loss is: 39261.456881178216
# When time is : 323, get best_k: 37.07832763435617 best_b: -13.967423560638041, and the loss is: 39050.70495843433
# When time is : 324, get best_k: 36.97832763435617 best_b: -13.867423560638041, and the loss is: 38840.52143680694
# When time is : 325, get best_k: 36.87832763435617 best_b: -13.767423560638042, and the loss is: 38630.906316295994
# When time is : 326, get best_k: 36.77832763435617 best_b: -13.667423560638042, and the loss is: 38421.859596901595
# When time is : 327, get best_k: 36.678327634356165 best_b: -13.567423560638042, and the loss is: 38213.38127862361
# When time is : 328, get best_k: 36.578327634356164 best_b: -13.467423560638043, and the loss is: 38005.47136146221
# When time is : 329, get best_k: 36.47832763435616 best_b: -13.367423560638043, and the loss is: 37798.129845417156
# When time is : 330, get best_k: 36.37832763435616 best_b: -13.267423560638044, and the loss is: 37591.35673048867
# When time is : 331, get best_k: 36.27832763435616 best_b: -13.167423560638044, and the loss is: 37385.152016676686
# When time is : 332, get best_k: 36.17832763435616 best_b: -13.067423560638044, and the loss is: 37179.51570398107
# When time is : 333, get best_k: 36.07832763435616 best_b: -12.967423560638045, and the loss is: 36974.44779240207
# When time is : 334, get best_k: 35.978327634356155 best_b: -12.867423560638045, and the loss is: 36769.94828193949
# When time is : 335, get best_k: 35.878327634356154 best_b: -12.767423560638045, and the loss is: 36566.017172593405
# When time is : 336, get best_k: 35.77832763435615 best_b: -12.667423560638046, and the loss is: 36362.654464363746
# When time is : 337, get best_k: 35.67832763435615 best_b: -12.567423560638046, and the loss is: 36159.86015725066
# When time is : 338, get best_k: 35.57832763435615 best_b: -12.467423560638046, and the loss is: 35957.63425125401
# When time is : 339, get best_k: 35.47832763435615 best_b: -12.367423560638047, and the loss is: 35755.976746373795
# When time is : 340, get best_k: 35.37832763435615 best_b: -12.267423560638047, and the loss is: 35554.88764261014
# When time is : 341, get best_k: 35.278327634356145 best_b: -12.167423560638047, and the loss is: 35354.36693996296
# When time is : 342, get best_k: 35.178327634356144 best_b: -12.067423560638048, and the loss is: 35154.41463843227
# When time is : 343, get best_k: 35.07832763435614 best_b: -11.967423560638048, and the loss is: 34955.030738018
# When time is : 344, get best_k: 34.97832763435614 best_b: -11.867423560638048, and the loss is: 34756.215238720244
# When time is : 345, get best_k: 34.87832763435614 best_b: -11.767423560638049, and the loss is: 34557.968140538986
# When time is : 346, get best_k: 34.77832763435614 best_b: -11.66742356063805, and the loss is: 34360.289443474234
# When time is : 347, get best_k: 34.67832763435614 best_b: -11.56742356063805, and the loss is: 34163.17914752592
# When time is : 348, get best_k: 34.578327634356135 best_b: -11.46742356063805, and the loss is: 33966.63725269403
# When time is : 349, get best_k: 34.478327634356134 best_b: -11.36742356063805, and the loss is: 33770.66375897872
# When time is : 350, get best_k: 34.37832763435613 best_b: -11.26742356063805, and the loss is: 33575.258666379894
# When time is : 351, get best_k: 34.27832763435613 best_b: -11.167423560638051, and the loss is: 33380.42197489747
# When time is : 352, get best_k: 34.17832763435613 best_b: -11.067423560638051, and the loss is: 33186.1536845316
# When time is : 353, get best_k: 34.07832763435613 best_b: -10.967423560638052, and the loss is: 32992.45379528219
# When time is : 354, get best_k: 33.97832763435613 best_b: -10.867423560638052, and the loss is: 32799.32230714922
# When time is : 355, get best_k: 33.878327634356125 best_b: -10.767423560638052, and the loss is: 32606.759220132793
# When time is : 356, get best_k: 33.778327634356124 best_b: -10.667423560638053, and the loss is: 32414.76453423283
# When time is : 357, get best_k: 33.67832763435612 best_b: -10.567423560638053, and the loss is: 32223.338249449334
# When time is : 358, get best_k: 33.57832763435612 best_b: -10.467423560638053, and the loss is: 32032.480365782336
# When time is : 359, get best_k: 33.47832763435612 best_b: -10.367423560638054, and the loss is: 31842.190883231808
# When time is : 360, get best_k: 33.37832763435612 best_b: -10.267423560638054, and the loss is: 31652.46980179778
# When time is : 361, get best_k: 33.27832763435612 best_b: -10.167423560638055, and the loss is: 31463.31712148022
# When time is : 362, get best_k: 33.178327634356116 best_b: -10.067423560638055, and the loss is: 31274.732842279158
# When time is : 363, get best_k: 33.078327634356114 best_b: -9.967423560638055, and the loss is: 31086.716964194562
# When time is : 364, get best_k: 32.97832763435611 best_b: -9.867423560638056, and the loss is: 30899.269487226484
# When time is : 365, get best_k: 32.87832763435611 best_b: -9.767423560638056, and the loss is: 30712.390411374843
# When time is : 366, get best_k: 32.77832763435611 best_b: -9.667423560638056, and the loss is: 30526.0797366397
# When time is : 367, get best_k: 32.67832763435611 best_b: -9.567423560638057, and the loss is: 30340.337463021027
# When time is : 368, get best_k: 32.57832763435611 best_b: -9.467423560638057, and the loss is: 30155.163590518878
# When time is : 369, get best_k: 32.478327634356106 best_b: -9.367423560638057, and the loss is: 29970.55811913316
# When time is : 370, get best_k: 32.378327634356104 best_b: -9.267423560638058, and the loss is: 29786.521048863942
# When time is : 371, get best_k: 32.2783276343561 best_b: -9.167423560638058, and the loss is: 29603.05237971123
# When time is : 372, get best_k: 32.1783276343561 best_b: -9.067423560638058, and the loss is: 29420.15211167496
# When time is : 373, get best_k: 32.0783276343561 best_b: -8.967423560638059, and the loss is: 29237.82024475521
# When time is : 374, get best_k: 31.9783276343561 best_b: -8.86742356063806, and the loss is: 29056.056778951897
# When time is : 375, get best_k: 31.878327634356097 best_b: -8.76742356063806, and the loss is: 28874.86171426512
# When time is : 376, get best_k: 31.778327634356096 best_b: -8.66742356063806, and the loss is: 28694.23505069476
# When time is : 377, get best_k: 31.678327634356094 best_b: -8.56742356063806, and the loss is: 28514.17678824095
# When time is : 378, get best_k: 31.578327634356093 best_b: -8.46742356063806, and the loss is: 28334.686926903596
# When time is : 379, get best_k: 31.47832763435609 best_b: -8.367423560638061, and the loss is: 28155.765466682744
# When time is : 380, get best_k: 31.37832763435609 best_b: -8.267423560638061, and the loss is: 27977.41240757832
# When time is : 381, get best_k: 31.27832763435609 best_b: -8.167423560638062, and the loss is: 27799.627749590436
# When time is : 382, get best_k: 31.178327634356087 best_b: -8.067423560638062, and the loss is: 27622.41149271896
# When time is : 383, get best_k: 31.078327634356086 best_b: -7.967423560638062, and the loss is: 27445.763636964028
# When time is : 384, get best_k: 30.978327634356084 best_b: -7.867423560638063, and the loss is: 27269.68418232557
# When time is : 385, get best_k: 30.878327634356083 best_b: -7.767423560638063, and the loss is: 27094.173128803584
# When time is : 386, get best_k: 30.77832763435608 best_b: -7.667423560638063, and the loss is: 26919.23047639811
# When time is : 387, get best_k: 30.67832763435608 best_b: -7.567423560638064, and the loss is: 26744.85622510908
# When time is : 388, get best_k: 30.57832763435608 best_b: -7.467423560638064, and the loss is: 26571.050374936527
# When time is : 389, get best_k: 30.478327634356077 best_b: -7.3674235606380645, and the loss is: 26397.812925880502
# When time is : 390, get best_k: 30.378327634356076 best_b: -7.267423560638065, and the loss is: 26225.14387794092
# When time is : 391, get best_k: 30.278327634356074 best_b: -7.167423560638065, and the loss is: 26053.04323111783
# When time is : 392, get best_k: 30.178327634356073 best_b: -7.0674235606380655, and the loss is: 25881.5109854112
# When time is : 393, get best_k: 30.07832763435607 best_b: -6.967423560638066, and the loss is: 25710.547140821072
# When time is : 394, get best_k: 29.97832763435607 best_b: -6.867423560638066, and the loss is: 25540.151697347468
# When time is : 395, get best_k: 29.87832763435607 best_b: -6.767423560638067, and the loss is: 25370.324654990283
# When time is : 396, get best_k: 29.778327634356067 best_b: -6.667423560638067, and the loss is: 25201.066013749634
# When time is : 397, get best_k: 29.678327634356066 best_b: -6.567423560638067, and the loss is: 25032.375773625452
# When time is : 398, get best_k: 29.578327634356064 best_b: -6.467423560638068, and the loss is: 24864.25393461773
# When time is : 399, get best_k: 29.478327634356063 best_b: -6.367423560638068, and the loss is: 24696.70049672652
# When time is : 400, get best_k: 29.37832763435606 best_b: -6.267423560638068, and the loss is: 24529.71545995174
# When time is : 401, get best_k: 29.27832763435606 best_b: -6.167423560638069, and the loss is: 24363.29882429347
# When time is : 402, get best_k: 29.17832763435606 best_b: -6.067423560638069, and the loss is: 24197.45058975172
# When time is : 403, get best_k: 29.078327634356057 best_b: -5.9674235606380694, and the loss is: 24032.170756326384
# When time is : 404, get best_k: 28.978327634356056 best_b: -5.86742356063807, and the loss is: 23867.459324017556
# When time is : 405, get best_k: 28.878327634356054 best_b: -5.76742356063807, and the loss is: 23703.316292825228
# When time is : 406, get best_k: 28.778327634356053 best_b: -5.6674235606380705, and the loss is: 23539.74166274934
# When time is : 407, get best_k: 28.67832763435605 best_b: -5.567423560638071, and the loss is: 23376.735433789985
# When time is : 408, get best_k: 28.57832763435605 best_b: -5.467423560638071, and the loss is: 23214.29760594709
# When time is : 409, get best_k: 28.47832763435605 best_b: -5.367423560638072, and the loss is: 23052.4281792207
# When time is : 410, get best_k: 28.378327634356047 best_b: -5.267423560638072, and the loss is: 22891.127153610778
# When time is : 411, get best_k: 28.278327634356046 best_b: -5.167423560638072, and the loss is: 22730.39452911734
# When time is : 412, get best_k: 28.178327634356044 best_b: -5.067423560638073, and the loss is: 22570.23030574037
# When time is : 413, get best_k: 28.078327634356043 best_b: -4.967423560638073, and the loss is: 22410.634483479902
# When time is : 414, get best_k: 27.97832763435604 best_b: -4.867423560638073, and the loss is: 22251.607062335926
# When time is : 415, get best_k: 27.87832763435604 best_b: -4.767423560638074, and the loss is: 22093.148042308385
# When time is : 416, get best_k: 27.77832763435604 best_b: -4.667423560638074, and the loss is: 21935.257423397357
# When time is : 417, get best_k: 27.678327634356037 best_b: -4.567423560638074, and the loss is: 21777.935205602796
# When time is : 418, get best_k: 27.578327634356036 best_b: -4.467423560638075, and the loss is: 21621.181388924746
# When time is : 419, get best_k: 27.478327634356035 best_b: -4.367423560638075, and the loss is: 21464.995973363137
# When time is : 420, get best_k: 27.378327634356033 best_b: -4.2674235606380755, and the loss is: 21309.378958918056
# When time is : 421, get best_k: 27.27832763435603 best_b: -4.167423560638076, and the loss is: 21154.330345589446
# When time is : 422, get best_k: 27.17832763435603 best_b: -4.067423560638076, and the loss is: 20999.850133377295
# ...
# When time is : 555, get best_k: 13.87832763435588 best_b: 9.23257643936191, and the loss is: 5519.004258136072
# When time is : 556, get best_k: 13.77832763435588 best_b: 9.33257643936191, and the loss is: 5440.689795532551
# When time is : 557, get best_k: 13.678327634355881 best_b: 9.43257643936191, and the loss is: 5362.943734045519
# When time is : 558, get best_k: 13.578327634355881 best_b: 9.53257643936191, and the loss is: 5285.766073674965
# When time is : 559, get best_k: 13.478327634355882 best_b: 9.632576439361909, and the loss is: 5209.156814420894
# When time is : 560, get best_k: 13.378327634355882 best_b: 9.732576439361909, and the loss is: 5133.115956283302
# When time is : 561, get best_k: 13.278327634355882 best_b: 9.832576439361908, and the loss is: 5057.643499262196
# When time is : 562, get best_k: 13.178327634355883 best_b: 9.932576439361908, and the loss is: 4982.739443357574
# When time is : 563, get best_k: 13.078327634355883 best_b: 10.032576439361907, and the loss is: 4908.403788569429
# When time is : 564, get best_k: 12.978327634355884 best_b: 10.132576439361907, and the loss is: 4834.636534897766
# When time is : 565, get best_k: 12.878327634355884 best_b: 10.232576439361907, and the loss is: 4761.437682342594
# When time is : 566, get best_k: 12.778327634355884 best_b: 10.332576439361906, and the loss is: 4688.807230903892
# When time is : 567, get best_k: 12.678327634355885 best_b: 10.432576439361906, and the loss is: 4616.745180581683
# When time is : 568, get best_k: 12.578327634355885 best_b: 10.532576439361906, and the loss is: 4545.2515313759495
# When time is : 569, get best_k: 12.478327634355885 best_b: 10.632576439361905, and the loss is: 4474.326283286701
# When time is : 570, get best_k: 12.378327634355886 best_b: 10.732576439361905, and the loss is: 4403.969436313935
# When time is : 571, get best_k: 12.278327634355886 best_b: 10.832576439361905, and the loss is: 4334.180990457647
# When time is : 572, get best_k: 12.178327634355886 best_b: 10.932576439361904, and the loss is: 4264.960945717841
# When time is : 573, get best_k: 12.078327634355887 best_b: 11.032576439361904, and the loss is: 4196.309302094524
# When time is : 574, get best_k: 11.978327634355887 best_b: 11.132576439361904, and the loss is: 4128.226059587687
# When time is : 575, get best_k: 11.878327634355887 best_b: 11.232576439361903, and the loss is: 4060.7112181973303
# When time is : 576, get best_k: 11.778327634355888 best_b: 11.332576439361903, and the loss is: 3993.76477792346
# When time is : 577, get best_k: 11.678327634355888 best_b: 11.432576439361902, and the loss is: 3927.3867387660625
# When time is : 578, get best_k: 11.578327634355889 best_b: 11.532576439361902, and the loss is: 3861.577100725158
# When time is : 579, get best_k: 11.478327634355889 best_b: 11.632576439361902, and the loss is: 3796.3358638007276
# When time is : 580, get best_k: 11.37832763435589 best_b: 11.732576439361901, and the loss is: 3731.663027992783
# When time is : 581, get best_k: 11.27832763435589 best_b: 11.832576439361901, and the loss is: 3667.558593301321
# When time is : 582, get best_k: 11.17832763435589 best_b: 11.9325764393619, and the loss is: 3604.022559726339
# When time is : 583, get best_k: 11.07832763435589 best_b: 12.0325764393619, and the loss is: 3541.05492726784
# When time is : 584, get best_k: 10.97832763435589 best_b: 12.1325764393619, and the loss is: 3478.655695925822
# When time is : 585, get best_k: 10.878327634355891 best_b: 12.2325764393619, and the loss is: 3416.824865700293
# When time is : 586, get best_k: 10.778327634355891 best_b: 12.3325764393619, and the loss is: 3355.562436591241
# When time is : 587, get best_k: 10.678327634355892 best_b: 12.432576439361899, and the loss is: 3294.8684085986697
# When time is : 588, get best_k: 10.578327634355892 best_b: 12.532576439361899, and the loss is: 3234.742781722584
# When time is : 589, get best_k: 10.478327634355892 best_b: 12.632576439361898, and the loss is: 3175.1855559629785
# When time is : 590, get best_k: 10.378327634355893 best_b: 12.732576439361898, and the loss is: 3116.1967313198547
# When time is : 591, get best_k: 10.278327634355893 best_b: 12.832576439361898, and the loss is: 3057.776307793215
# When time is : 592, get best_k: 10.178327634355893 best_b: 12.932576439361897, and the loss is: 2999.9242853830547
# When time is : 593, get best_k: 10.078327634355894 best_b: 13.032576439361897, and the loss is: 2942.64066408938
# When time is : 594, get best_k: 9.978327634355894 best_b: 13.132576439361896, and the loss is: 2885.9254439121846
# When time is : 595, get best_k: 9.878327634355895 best_b: 13.232576439361896, and the loss is: 2829.7786248514735
# When time is : 596, get best_k: 9.778327634355895 best_b: 13.332576439361896, and the loss is: 2774.200206907243
# When time is : 597, get best_k: 9.678327634355895 best_b: 13.432576439361895, and the loss is: 2719.190190079494
# When time is : 598, get best_k: 9.578327634355896 best_b: 13.532576439361895, and the loss is: 2664.7485743682314
# When time is : 599, get best_k: 9.478327634355896 best_b: 13.632576439361895, and the loss is: 2610.875359773447
# When time is : 600, get best_k: 9.378327634355896 best_b: 13.732576439361894, and the loss is: 2557.570546295147
# When time is : 601, get best_k: 9.278327634355897 best_b: 13.832576439361894, and the loss is: 2504.8341339333288
# When time is : 602, get best_k: 9.178327634355897 best_b: 13.932576439361894, and the loss is: 2452.6661226879905
# When time is : 603, get best_k: 9.078327634355897 best_b: 14.032576439361893, and the loss is: 2401.0665125591395
# When time is : 604, get best_k: 8.978327634355898 best_b: 14.132576439361893, and the loss is: 2350.0353035467674
# When time is : 605, get best_k: 8.878327634355898 best_b: 14.232576439361893, and the loss is: 2299.5724956508757
# When time is : 606, get best_k: 8.778327634355898 best_b: 14.332576439361892, and the loss is: 2249.6780888714698
# When time is : 607, get best_k: 8.678327634355899 best_b: 14.432576439361892, and the loss is: 2200.3520832085446
# When time is : 608, get best_k: 8.5783276343559 best_b: 14.532576439361891, and the loss is: 2151.594478662099
# When time is : 609, get best_k: 8.4783276343559 best_b: 14.632576439361891, and the loss is: 2103.40527523214
# When time is : 610, get best_k: 8.3783276343559 best_b: 14.73257643936189, and the loss is: 2055.784472918661
# When time is : 611, get best_k: 8.2783276343559 best_b: 14.83257643936189, and the loss is: 2008.7320717216646
# When time is : 612, get best_k: 8.1783276343559 best_b: 14.93257643936189, and the loss is: 1962.2480716411503
# When time is : 613, get best_k: 8.078327634355901 best_b: 15.03257643936189, and the loss is: 1916.3324726771184
# When time is : 614, get best_k: 7.978327634355901 best_b: 15.13257643936189, and the loss is: 1870.9852748295668
# When time is : 615, get best_k: 7.878327634355902 best_b: 15.232576439361889, and the loss is: 1826.2064780984997
# When time is : 616, get best_k: 7.778327634355902 best_b: 15.332576439361889, and the loss is: 1781.996082483915
# When time is : 617, get best_k: 7.678327634355902 best_b: 15.432576439361888, and the loss is: 1738.3540879858122
# When time is : 618, get best_k: 7.578327634355903 best_b: 15.532576439361888, and the loss is: 1695.280494604191
# When time is : 619, get best_k: 7.478327634355903 best_b: 15.632576439361888, and the loss is: 1652.7753023390517
# When time is : 620, get best_k: 7.378327634355903 best_b: 15.732576439361887, and the loss is: 1610.8385111903954
# When time is : 621, get best_k: 7.278327634355904 best_b: 15.832576439361887, and the loss is: 1569.4701211582214
# When time is : 622, get best_k: 7.178327634355904 best_b: 15.932576439361887, and the loss is: 1528.6701322425279
# When time is : 623, get best_k: 7.0783276343559045 best_b: 16.032576439361886, and the loss is: 1488.4385444433174
# When time is : 624, get best_k: 6.978327634355905 best_b: 16.132576439361888, and the loss is: 1448.7753577605904
# When time is : 625, get best_k: 6.878327634355905 best_b: 16.23257643936189, and the loss is: 1409.6805721943444
# When time is : 626, get best_k: 6.778327634355906 best_b: 16.33257643936189, and the loss is: 1371.1541877445823
# When time is : 627, get best_k: 6.678327634355906 best_b: 16.432576439361892, and the loss is: 1333.1962044112995
# When time is : 628, get best_k: 6.578327634355906 best_b: 16.532576439361893, and the loss is: 1295.8066221945012
# When time is : 629, get best_k: 6.478327634355907 best_b: 16.632576439361895, and the loss is: 1258.9854410941853
# When time is : 630, get best_k: 6.378327634355907 best_b: 16.732576439361896, and the loss is: 1222.7326611103501
# When time is : 631, get best_k: 6.278327634355907 best_b: 16.832576439361898, and the loss is: 1187.0482822429988
# When time is : 632, get best_k: 6.178327634355908 best_b: 16.9325764393619, and the loss is: 1151.9323044921293
# When time is : 633, get best_k: 6.078327634355908 best_b: 17.0325764393619, and the loss is: 1117.384727857742
# When time is : 634, get best_k: 5.978327634355908 best_b: 17.132576439361902, and the loss is: 1083.405552339836
# When time is : 635, get best_k: 5.878327634355909 best_b: 17.232576439361903, and the loss is: 1049.9947779384113
# When time is : 636, get best_k: 5.778327634355909 best_b: 17.332576439361905, and the loss is: 1017.1524046534705
# When time is : 637, get best_k: 5.6783276343559095 best_b: 17.432576439361906, and the loss is: 984.8784324850117
# When time is : 638, get best_k: 5.57832763435591 best_b: 17.532576439361907, and the loss is: 953.1728614330364
# When time is : 639, get best_k: 5.47832763435591 best_b: 17.63257643936191, and the loss is: 922.0356914975404
# When time is : 640, get best_k: 5.3783276343559105 best_b: 17.73257643936191, and the loss is: 891.4669226785276
# When time is : 641, get best_k: 5.278327634355911 best_b: 17.83257643936191, and the loss is: 861.4665549759981
# When time is : 642, get best_k: 5.178327634355911 best_b: 17.932576439361913, and the loss is: 832.0345883899511
# When time is : 643, get best_k: 5.078327634355912 best_b: 18.032576439361915, and the loss is: 803.1710229203848
# When time is : 644, get best_k: 4.978327634355912 best_b: 18.132576439361916, and the loss is: 774.8758585672998
# When time is : 645, get best_k: 4.878327634355912 best_b: 18.232576439361917, and the loss is: 747.1490953306993
# When time is : 646, get best_k: 4.778327634355913 best_b: 18.33257643936192, and the loss is: 719.9907332105805
# When time is : 647, get best_k: 4.678327634355913 best_b: 18.43257643936192, and the loss is: 693.4007722069429
# When time is : 648, get best_k: 4.578327634355913 best_b: 18.53257643936192, and the loss is: 667.3792123197882
# When time is : 649, get best_k: 4.478327634355914 best_b: 18.632576439361923, and the loss is: 641.9260535491156
# When time is : 650, get best_k: 4.378327634355914 best_b: 18.732576439361925, and the loss is: 617.0412958949258
# When time is : 651, get best_k: 4.2783276343559145 best_b: 18.832576439361926, and the loss is: 592.7249393572176
# When time is : 652, get best_k: 4.178327634355915 best_b: 18.932576439361927, and the loss is: 568.9769839359922
# When time is : 653, get best_k: 4.078327634355915 best_b: 19.03257643936193, and the loss is: 545.7974296312481
# When time is : 654, get best_k: 3.978327634355915 best_b: 19.13257643936193, and the loss is: 523.1862764429859
# When time is : 655, get best_k: 3.878327634355915 best_b: 19.23257643936193, and the loss is: 501.1435243712067
# When time is : 656, get best_k: 3.778327634355915 best_b: 19.332576439361933, and the loss is: 479.6691734159099
# When time is : 657, get best_k: 3.678327634355915 best_b: 19.432576439361934, and the loss is: 458.7632235770944
# When time is : 658, get best_k: 3.5783276343559147 best_b: 19.532576439361936, and the loss is: 438.42567485476206
# When time is : 659, get best_k: 3.4783276343559146 best_b: 19.632576439361937, and the loss is: 418.6565272489108
# When time is : 660, get best_k: 3.3783276343559145 best_b: 19.73257643936194, and the loss is: 399.4557807595426
# When time is : 661, get best_k: 3.2783276343559145 best_b: 19.83257643936194, and the loss is: 380.82343538665697
# When time is : 662, get best_k: 3.1783276343559144 best_b: 19.93257643936194, and the loss is: 362.75949113025314
# When time is : 663, get best_k: 3.0783276343559143 best_b: 20.032576439361943, and the loss is: 345.2639479903316
# When time is : 664, get best_k: 2.978327634355914 best_b: 20.132576439361944, and the loss is: 328.3368059668918
# When time is : 665, get best_k: 2.878327634355914 best_b: 20.232576439361946, and the loss is: 311.9780650599342
# When time is : 666, get best_k: 2.778327634355914 best_b: 20.332576439361947, and the loss is: 296.1877252694594
# When time is : 667, get best_k: 2.678327634355914 best_b: 20.43257643936195, and the loss is: 280.96578659546645
# When time is : 668, get best_k: 2.578327634355914 best_b: 20.53257643936195, and the loss is: 266.3122490379559
# When time is : 669, get best_k: 2.4783276343559137 best_b: 20.63257643936195, and the loss is: 252.22711259692744
# When time is : 670, get best_k: 2.3783276343559137 best_b: 20.732576439361953, and the loss is: 238.71037727238132
# When time is : 671, get best_k: 2.2783276343559136 best_b: 20.832576439361954, and the loss is: 225.76204306431734
# When time is : 672, get best_k: 2.1783276343559135 best_b: 20.932576439361956, and the loss is: 213.3821099727356
# When time is : 673, get best_k: 2.0783276343559134 best_b: 21.032576439361957, and the loss is: 201.57057799763578
# When time is : 674, get best_k: 1.9783276343559133 best_b: 21.13257643936196, and the loss is: 190.32744713901835
# When time is : 675, get best_k: 1.8783276343559132 best_b: 21.23257643936196, and the loss is: 179.6527173968832
# When time is : 676, get best_k: 1.7783276343559131 best_b: 21.33257643936196, and the loss is: 169.5463887712305
# When time is : 677, get best_k: 1.678327634355913 best_b: 21.432576439361963, and the loss is: 160.00846126205946
# When time is : 678, get best_k: 1.578327634355913 best_b: 21.532576439361964, and the loss is: 151.03893486937116
# When time is : 679, get best_k: 1.4783276343559129 best_b: 21.632576439361966, and the loss is: 142.6378095931646
# When time is : 680, get best_k: 1.3783276343559128 best_b: 21.732576439361967, and the loss is: 134.8050854334407
# When time is : 681, get best_k: 1.2783276343559127 best_b: 21.83257643936197, and the loss is: 127.54076239019872
# When time is : 682, get best_k: 1.1783276343559126 best_b: 21.93257643936197, and the loss is: 120.84484046343911
# When time is : 683, get best_k: 1.0783276343559125 best_b: 22.03257643936197, and the loss is: 114.7173196531616
# When time is : 684, get best_k: 0.9783276343559125 best_b: 22.132576439361973, and the loss is: 109.15819995936631
# When time is : 685, get best_k: 0.8783276343559125 best_b: 22.232576439361974, and the loss is: 104.16748138205315
# When time is : 686, get best_k: 0.7783276343559126 best_b: 22.332576439361976, and the loss is: 99.74516392122237
# When time is : 687, get best_k: 0.6783276343559126 best_b: 22.432576439361977, and the loss is: 95.89124757687388
# When time is : 688, get best_k: 0.5783276343559126 best_b: 22.53257643936198, and the loss is: 92.60573234900743
# When time is : 689, get best_k: 0.47832763435591263 best_b: 22.63257643936198, and the loss is: 89.88861823762318
# When time is : 690, get best_k: 0.37832763435591266 best_b: 22.73257643936198, and the loss is: 87.7399052427212
# When time is : 691, get best_k: 0.2783276343559127 best_b: 22.832576439361983, and the loss is: 86.15959336430141
# When time is : 692, get best_k: 0.17832763435591267 best_b: 22.932576439361984, and the loss is: 85.14768260236387
# When time is : 693, get best_k: 0.07832763435591267 best_b: 23.032576439361986, and the loss is: 84.70417295690847
# When time is : 695, get best_k: -0.021672365644087338 best_b: 22.932576439361984, and the loss is: 84.6836375395876
# When time is : 697, get best_k: 0.07832763435591267 best_b: 22.832576439361983, and the loss is: 84.34736069306678

# %% [markdown]
# ###### 3.Gradient Descent to get optimal *k* and *b*

# %% [markdown]
# ###### 4. Try different Loss function and learning rate.

# %% [markdown]
# For example, you can change the loss function: $Loss = \frac{1}{n} sum({y_i - \hat{y_i}})^2$ to $Loss = \frac{1}{n} sum(|{y_i - \hat{y_i}}|)$
#
# And you can change the learning rate and observe the performance.

# %% [markdown]
# ![](https://timgsa.baidu.com/timg?image&quality=80&size=b9999_10000&sec=1562414412237&di=8377c38d7b50c6f8d45b92ccc78dc1e7&imgtype=0&src=http%3A%2F%2Fmmbiz.qpic.cn%2Fmmbiz_jpg%2FlSyiavfm6wPgQDuDYa42IMgSkLOcPJU91RbkMibGy7VHLrhhNVLibTYk1iaLcmXKTdHc4icTDVia59QFXwqpW8cLflaw%2F640%3Fwx_fmt%3Djpeg)

# %% [markdown]
# ## 2. Answer following questions:
#
#
# ###### 1. Why do we need machine learning methods instead of creating a complicated formula?

# %% [markdown]
# Ans:人工无法处理过于复杂的公式，机器学习可以自动调节参数生成公式

# %% [markdown]
# ###### 2.  Wha't's the disadvantages of `the 1st Random Choosen` methods in our course?

# %% [markdown]
# Ans:优化所需次数较大，收敛慢

# %% [markdown]
# ###### 3. Is the `2nd method supervised direction` better than 1st one?  What's the disadvantages of `the 2nd supversied directin` method?

# %% [markdown]
# Ans:第二种方法比第一种方法好，第二种方法方向的选择是随机，随机到不对的方向产生无效计算

# %% [markdown]
# ###### 4. Why do we use `Derivative / Gredient` to fit a target function?

# %% [markdown]
# Ans:通过计算导数得到函数变化情况，使得结果更快收敛

# %% [markdown]
# ###### 5. In the words 'Gredient Descent', what's the `Gredient` and what's the `Descent`?

# %% [markdown]
# Ans:梯度即导数，下降就是沿导线减小的方向优化

# %% [markdown]
# ###### 6. What's the advantages of `the 3rd gradient descent method` compared to the previous methods?

# %% [markdown]
# Ans:通过计算导数使得函数不断向最优值方向变化，得到最优值所需的计算量较少

# %% [markdown]
# ###### 7. Using the simple words to describe: What's the machine leanring.

# %% [markdown]
# Ans:用计算手段，学习经验改善系统性能

# %% [markdown]
# ## 3. Finish the search problem

# %% [markdown]
# Please using the search policy to implement an agent. This agent receives two input, one is @param start station and the other is @param destination. Your agent should give the optimal route based on Beijing Subway system.

# %% [markdown]
# > Deadline: 2019-July-13
#
# >Submit: Submit the source code and result to github.

# %% [markdown]
# ![](https://timgsa.baidu.com/timg?image&quality=80&size=b9999_10000&sec=1562414356407&di=b57814aafd215bb8b8d9d8cd37c573d6&imgtype=0&src=http%3A%2F%2Fcli.clewm.net%2Ffile%2F2015%2F03%2F24%2F174ed60082b8422ac0636cfd3efb9e7f.jpg)

# %% [markdown]
# #### Dataflow:

# %% [markdown]
# ##### 1.	Get data from web page.
#
# > a.	Get web page source from: https://baike.baidu.com/item/%E5%8C%97%E4%BA%AC%E5%9C%B0%E9%93%81/408485
#
# > b.	You may need @package **requests**[https://2.python-requests.org/en/master/] page to get the response via url
#
# > c.	You may need save the page source to file system.
#
# > d.	The target of this step is to get station information of all the subway lines;
#
# > e.	You may need install @package beautiful soup[https://www.crummy.com/software/BeautifulSoup/bs4/doc/]  to get the url information, or just use > Regular Expression to get the url.  Our recommendation is that using the Regular Expression and BeautiflSoup both.
#
# > f.	You may need BFS to get all the related page url from one url.
# Question: Why do we use BFS to traverse web page (or someone said, build a web spider)?  Can DFS do this job? which is better?
#
# > ans:	 广度优先遍历可以设置爬取深度，减少不需要的内容，深度优先遍历会爬取到网站以外的内容，停不下来

# %%
import re
import requests
from bs4 import BeautifulSoup

# %%
import sys
from PyQt5.QtCore import QUrl
from PyQt5.QtWidgets import QApplication
from PyQt5.QtWebEngineWidgets import QWebEnginePage, QWebEngineView

# %%
# 站点坐标
location_url = 'https://map.bjsubway.com/'
# 北京地铁时间信息
time_info_url = 'http://www.bjsubway.com/e/action/ListInfo/?classid=39&ph=1'
# 北京地铁距离信息
distance_info_url = 'http://www.bjsubway.com/station/zjgls/'

# %%
# 站点坐标: {name: (x, y)}
location_map = {}
# 两站之间连接的信息: {hash(name1)+hash(name2):Connection}
p2p_map = {}
# 与相邻站的连接: {name:{next1, next2, ...}}
connection_map = {}

# %%
class Render(QWebEngineView):
    """
    PyQt爬取地铁地图
    """
    def __init__(self, url):
        self.app = QApplication(sys.argv)
        QWebEngineView.__init__(self)
        self.loadFinished.connect(self._loadFinished)
        self.load(QUrl(url))
        self.app.exec_()
    
    def _loadFinished(self, result):
        # This is an async call, you need to wait for this
        # to be called before closing the app
        self.page().toHtml(self.callable)
    
    def callable(self, data):
        self.html = data
        # Data has been stored, it's safe to quit the app
        self.app.quit()
        

def get_hash(name1, name2):
    return hash(name1) + hash(name2)

class Connection:
    """
    两站之间连接的信息
    name1: 第一站名称
    name2: 第二站名称
    diff_time: 两站之间所需时间，分钟
    distance: 两站之间的距离，米
    """

    def __init__(self, name1, name2):
        self.name1 = name1
        self.name2 = name2
        self.diff_time = None
        self.distance = None

    def __hash__(self):
        return get_hash(self.name1, self.name2)

    def __str__(self):
        return "{}-{}:{},{}".format(self.name1, self.name2, self.diff_time, self.distance)

    def __eq__(self, other):
        return self.__hash__() == other.hash()

    def hash(self):
        return self.__hash__()

    def next(self, name):
        if name == self.name1:
            return self.name2
        else:
            return self.name1


def add_connection(name1, name2):
    if name1 in connection_map:
        connection_map[name1].add(name2)
    else:
        connection_map[name1] = {name2}


def get_connection(name1, name2):
    key = get_hash(name1, name2)
    if key in p2p_map:
        return p2p_map[key]
    else:
        return None
        

def parse_time_table(table_data):
    """
    解析站间时间
    """
    def parse_time(string):
        split = string.split(':')
        if len(split) == 2:
            return int(split[0]) * 60 + int(split[1])
        else:
            return None

    def build_time_connection(row1, row2):
        if len(row1) != len(row2):
            return
        name = row1[0]
        next_name = row2[0]
        diff_time = None
        for j in range(1, min(len(row1), len(row2))):
            time = parse_time(row1[j])
            next_time = parse_time(row2[j])
            if time and next_time:
                diff_time = abs(time - next_time)
                break
        conn = Connection(name, next_name)
        if conn.hash() in p2p_map:
            p2p_map[conn.hash()].diff_time = diff_time
        else:
            conn.diff_time = diff_time
            p2p_map[conn.hash()] = conn
        add_connection(conn.name1, conn.name2)
        add_connection(conn.name2, conn.name1)

    for i, row in enumerate(table_data):
        if i > 0:
            build_time_connection(row, table_data[i - 1])
        if i < len(table_data) - 1:
            build_time_connection(row, table_data[i + 1])


def init_connection_time():
    """
    获取站间时间信息
    """
    response = requests.get(time_info_url)
    soup = BeautifulSoup(response.text, 'html.parser')
    tables = soup.find_all('table')
    for table in tables:
        table_data = []
        for tr in table.find_all('tr'):
            row = []
            for td in tr.find_all(['th', 'td']):
                text = td.getText().strip()
                if text == '生物医院基地': # 4号线名称标错了
                    text = '生物医药基地'
                row.append(text)
            table_data.append(row)
        print("parse:", table_data[0])
        parse_time_table(table_data[3:])


def parse_distance_table(table_data):
    """
    解析站间的距离
    """
    for row in table_data:
        split = row[0].split('――')
        name1 = split[0]
        name2 = split[1]
        distance = int(row[1])
        conn = Connection(name1, name2)
        if conn.hash() in p2p_map:
            p2p_map[conn.hash()].distance = distance
        else:
            conn.distance = distance
            p2p_map[conn.hash()] = conn
        add_connection(conn.name1, conn.name2)
        add_connection(conn.name2, conn.name1)


def init_connection_distance():
    """
    获取站间距离信息
    """
    response = requests.get(distance_info_url)
    response.encoding = 'gb2312'
    soup = BeautifulSoup(response.text, 'html.parser')
    tables = soup.find_all('table')
    for table in tables:
        table_data = []
        for tr in table.find_all('tr'):
            row = []
            for td in tr.find_all(['th', 'td']):
                row.append(td.getText().strip())
            table_data.append(row)
        print("parse:", table_data[0])
        parse_distance_table([row[:2] for row in table_data[2:]])


def init_location():
    r = Render(location_url)
    soup = BeautifulSoup(r.html, 'html.parser')
    g = soup.find(id='SvgjsG1008')
    for i in g.select('circle[sdata]'):    # 换乘站
        name = i.attrs['sdata']
        if name == '2号航站楼': name = 'T2航站楼'
        if name == '3号航站楼': name = 'T3航站楼'
        location_map[name] = (float(i.attrs['cx']), float(i.attrs['cy']))
    for i in g.select('image[sdata]'):
        location_map[i.attrs['sdata']] = (float(i.attrs['x']), float(i.attrs['y']))
    # 如果地图上没有则去相连站点的位置中点
    for name, conns in connection_map.items():
        if name in location_map: continue
        xs = []
        ys = []
        for conn in conns:
            xs.append(location_map[conn][0])
            ys.append(location_map[conn][1])
        location_map[name] = (sum(xs)/len(xs), sum(ys)/len(ys))

# %%
# 初始化时间信息
init_connection_time()
# Out:
# parse: ['1号线首末车时刻表']
# parse: ['2号线首末车时刻表']
# parse: ['4号线/大兴线首末车时刻表']
# parse: ['5号线首末车时刻表']
# parse: ['6号线首末车时刻表']
# parse: ['7号线首末车时刻表']
# parse: ['8号线（北段）首末车时刻表']
# parse: ['8号线（南段）首末车时刻表']
# parse: ['9号线首末车时刻表']
# parse: ['10号线首末车时刻表']
# parse: ['13号线首末车时刻表']
# parse: ['14号线（西段）首末车时刻表']
# parse: ['14号线东段（含中段）首末车时刻表']
# parse: ['15号线首末车时刻表']
# parse: ['16号线首末车时刻表']
# parse: ['八通线首末车时刻表']
# parse: ['昌平线首末车时刻表']
# parse: ['亦庄线首末车时刻表']
# parse: ['4号线/大兴线首末车时刻表']
# parse: ['房山线首末车时刻表']
# parse: ['S1线首末车时刻表']
# parse: ['燕房线首末车时刻表']

# %%
# 初始化距离信息
init_connection_distance()
# Out:
# parse: ['1号线相邻站间距信息统计表']
# parse: ['2号线相邻站间距信息统计表']
# parse: ['4号线相邻站间距信息统计表']
# parse: ['5号线相邻站间距信息统计表']
# parse: ['6号线相邻站间距信息统计表']
# parse: ['7号线相邻站间距信息统计表']
# parse: ['8号线相邻站间距信息统计表']
# parse: ['9号线相邻站间距信息统计表']
# parse: ['10号线相邻站间距信息统计表']
# parse: ['13号线相邻站间距信息统计表']
# parse: ['14号线(西段)相邻站间距信息统计表']
# parse: ['14号线（东段）相邻站间距信息统计表']
# parse: ['15号线相邻站间距信息统计表']
# parse: ['八通线相邻站间距信息统计表']
# parse: ['昌平线相邻站间距信息统计表']
# parse: ['亦庄线相邻站间距信息统计表']
# parse: ['大兴线相邻站间距信息统计表']
# parse: ['房山线相邻站间距信息统计表']
# parse: ['机场线相邻站间距信息统计表']

# %%
# 初始化坐标
init_location()

# %%
location_map
# Out:
# {'苹果园': (280.0, 760.0),
#  '古城': (310.0, 790.0),
#  '八角游乐园': (363.0, 790.0),
#  '八宝山': (407.0, 790.0),
#  '玉泉路': (448.0, 790.0),
#  '五棵松': (488.0, 790.0),
#  '万寿路': (533.0, 790.0),
#  '木樨地': (688.0, 790.0),
#  '南礼士路': (733.0, 790.0),
#  '天安门西': (922.0, 790.0),
#  '天安门东': (979.0, 790.0),
#  '王府井': (1034.0, 790.0),
#  '永安里': (1184.0, 790.0),
#  '积水潭': (851.0, 632.0),
#  '安定门': (1007.0, 632.0),
#  '东四十条': (1134.0, 698.0),
#  '北京站': (1128.0, 836.0),
#  '前门': (951.0, 841.0),
#  '和平门': (904.0, 841.0),
#  '长椿街': (787.0, 833.0),
#  '阜成门': (783.0, 750.0),
#  '安河桥北': (457.0, 410.0),
#  '北宫门': (516.0, 410.0),
#  '圆明园': (628.0, 438.0),
#  '北京大学东门': (628.0, 472.0),
#  '中关村': (628.0, 500.0),
#  '人民大学': (628.0, 587.0),
#  '魏公村': (628.0, 626.0),
#  '动物园': (710.0, 660.0),
#  '新街口': (848.0, 660.0),
#  '西四': (862.0, 738.0),
#  '灵境胡同': (862.0, 760.0),
#  '陶然亭': (862.0, 896.0),
#  '马家堡': (862.0, 950.0),
#  '公益西桥': (862.0, 1005.0),
#  '新宫': (848.0, 1023.0),
#  '西红门': (833.0, 1040.0),
#  '高米店北': (833.0, 1060.0),
#  '高米店南': (833.0, 1082.0),
#  '枣园': (833.0, 1101.0),
#  '清源路': (833.0, 1120.0),
#  '黄村西大街': (833.0, 1142.0),
#  '黄村火车站': (833.0, 1163.0),
#  '义和庄': (833.0, 1187.0),
#  '生物医药基地': (833.0, 1206.0),
#  '天宫院': (833.0, 1229.0),
#  '天通苑北': (1065.0, 276.0),
#  '天通苑': (1065.0, 309.0),
#  '天通苑南': (1065.0, 347.0),
#  '立水桥南': (1065.0, 410.0),
#  '北苑路北': (1065.0, 441.0),
#  '惠新西街北口': (1065.0, 511.0),
#  '和平西桥': (1065.0, 581.0),
#  '和平里北街': (1065.0, 606.0),
#  '北新桥': (1065.0, 667.0),
#  '张自忠路': (1065.0, 693.0),
#  '灯市口': (1065.0, 763.0),
#  '天坛东门': (1065.0, 896.0),
#  '刘家窑': (1065.0, 950.0),
#  '杨庄': (314.0, 734.0),
#  '西黄村': (347.0, 710.0),
#  '廖公庄': (397.0, 710.0),
#  '田村': (440.0, 710.0),
#  '海淀五路居': (487.0, 710.0),
#  '花园桥': (580.0, 710.0),
#  '车公庄西': (729.0, 710.0),
#  '北海北': (913.0, 710.0),
#  '东大桥': (1181.0, 738.0),
#  '十里堡': (1330.0, 738.0),
#  '青年路': (1372.0, 738.0),
#  '褡裢坡': (1415.0, 738.0),
#  '黄渠': (1457.0, 738.0),
#  '常营': (1500.0, 738.0),
#  '草房': (1542.0, 738.0),
#  '物资学院路': (1600.0, 738.0),
#  '通州北关': (1650.0, 750.0),
#  '通运门': (1675.0, 780.0),
#  '北运河西': (1700.0, 810.0),
#  '北运河东': (1730.0, 810.0),
#  '郝家府': (1758.0, 810.0),
#  '东夏园': (1790.0, 810.0),
#  '潞城': (1820.0, 810.0),
#  '湾子': (682.0, 867.0),
#  '达官营': (738.0, 867.0),
#  '广安门内': (800.0, 867.0),
#  '虎坊桥': (920.0, 867.0),
#  '桥湾': (1014.0, 867.0),
#  '广渠门内': (1113.0, 867.0),
#  '广渠门外': (1159.0, 867.0),
#  '大郊亭': (1338.0, 867.0),
#  '百子湾': (1371.0, 867.0),
#  '化工': (1381.0, 886.0),
#  '南楼梓庄': (1381.0, 909.0),
#  '欢乐谷景区': (1381.0, 930.0),
#  '垡头': (1396.0, 943.0),
#  '双合': (1422.0, 943.0),
#  '焦化厂': (1459.0, 943.0),
#  '育知路': (849.0, 325.0),
#  '平西府': (890.0, 325.0),
#  '回龙观东大街': (914.0, 352.0),
#  '育新': (914.0, 400.0),
#  '西小口': (914.0, 420.0),
#  '永泰庄': (914.0, 439.0),
#  '林萃桥': (933.0, 452.0),
#  '森林公园南门': (950.0, 463.0),
#  '奥体中心': (950.0, 509.0),
#  '安华桥': (950.0, 573.0),
#  '安德里北街': (950.0, 597.0),
#  '什刹海': (950.0, 670.0),
#  '中国美术馆': (1000.0, 740.0),
#  '天桥': (960.0, 896.0),
#  '木樨园': (960.0, 942.0),
#  '海户屯': (960.0, 958.0),
#  '大红门': (960.0, 974.0),
#  '大红门南': (960.0, 1007.0),
#  '和义': (960.0, 1033.0),
#  '东高地': (980.0, 1053.0),
#  '火箭万源': (1007.0, 1080.0),
#  '五福堂': (1032.0, 1105.0),
#  '德茂': (1052.0, 1125.0),
#  '瀛海': (1072.0, 1145.0),
#  '丰台科技园': (548.0, 1000.0),
#  '科怡路': (548.0, 977.0),
#  '丰台南路': (548.0, 952.0),
#  '丰台东大街': (548.0, 927.0),
#  '六里桥东': (616.0, 849.0),
#  '白堆子': (628.0, 750.0),
#  '丰台站': (611.0, 974.0),
#  '泥洼': (589.0, 949.0),
#  '莲花桥': (589.0, 828.0),
#  '西钓鱼台': (564.0, 751.0),
#  '车道沟': (534.0, 667.0),
#  '长春桥': (534.0, 626.0),
#  '火器营': (534.0, 585.0),
#  '苏州街': (570.0, 543.0),
#  '知春里': (671.0, 543.0),
#  '西土城': (810.0, 543.0),
#  '牡丹园': (857.0, 543.0),
#  '健德门': (900.0, 543.0),
#  '安贞门': (1008.0, 543.0),
#  '太阳宫': (1224.0, 549.0),
#  '亮马桥': (1236.0, 628.0),
#  '农业展览馆': (1236.0, 659.0),
#  '团结湖': (1236.0, 692.0),
#  '金台夕照': (1236.0, 761.0),
#  '双井': (1236.0, 867.0),
#  '劲松': (1236.0, 885.0),
#  '潘家园': (1236.0, 900.0),
#  '分钟寺': (1230.0, 965.0),
#  '成寿寺': (1144.0, 974.0),
#  '石榴庄': (1016.0, 974.0),
#  '角门东': (916.0, 974.0),
#  '草桥': (783.0, 974.0),
#  '纪家庙': (729.0, 974.0),
#  '首经贸': (670.0, 974.0),
#  '大钟寺': (757.0, 598.0),
#  '五道口': (757.0, 502.0),
#  '上地': (757.0, 466.0),
#  '龙泽': (801.0, 380.0),
#  '回龙观': (849.0, 380.0),
#  '北苑': (1153.0, 414.0),
#  '光熙门': (1153.0, 588.0),
#  '柳芳': (1153.0, 618.0),
#  '大井': (493.0, 900.0),
#  '郭庄子': (442.0, 900.0),
#  '大瓦窑': (390.0, 900.0),
#  '园博园': (337.0, 900.0),
#  '张郭庄': (284.0, 900.0),
#  '善各庄': (1219.0, 408.0),
#  '来广营': (1219.0, 436.0),
#  '东湖渠': (1219.0, 461.0),
#  '阜通': (1240.0, 520.0),
#  '望京南': (1270.0, 541.0),
#  '高家园': (1288.0, 590.0),
#  '将台': (1288.0, 612.0),
#  '东风北桥': (1288.0, 637.0),
#  '枣营': (1288.0, 665.0),
#  '朝阳公园': (1288.0, 697.0),
#  '平乐园': (1288.0, 895.0),
#  '北工大西门': (1270.0, 925.0),
#  '方庄': (1140.0, 925.0),
#  '景泰': (1000.0, 925.0),
#  '陶然桥': (915.0, 925.0),
#  '清华东路西口': (780.0, 481.0),
#  '六道口': (838.0, 481.0),
#  '北沙滩': (894.0, 481.0),
#  '安立路': (999.0, 481.0),
#  '关庄': (1110.0, 481.0),
#  '望京东': (1274.0, 481.0),
#  '崔各庄': (1301.0, 450.0),
#  '马泉营': (1301.0, 418.0),
#  '孙河': (1301.0, 384.0),
#  '国展': (1301.0, 351.0),
#  '花梨坎': (1301.0, 319.0),
#  '后沙峪': (1301.0, 284.0),
#  '南法信': (1365.0, 270.0),
#  '石门': (1446.0, 270.0),
#  '顺义': (1523.0, 270.0),
#  '俸伯': (1612.0, 270.0),
#  '农大南路': (567.0, 370.0),
#  '马连洼': (567.0, 335.0),
#  '西北旺': (567.0, 300.0),
#  '永丰南': (560.0, 262.0),
#  '永丰': (523.0, 245.0),
#  '屯佃': (480.0, 245.0),
#  '稻香湖路': (437.0, 245.0),
#  '温阳路': (395.0, 245.0),
#  '北安河': (348.0, 245.0),
#  '高碑店': (1413.0, 799.0),
#  '传媒大学': (1452.0, 799.0),
#  '双桥': (1496.0, 799.0),
#  '管庄': (1539.0, 799.0),
#  '八里桥': (1587.0, 799.0),
#  '通州北苑': (1613.0, 812.0),
#  '果园': (1631.0, 831.0),
#  '九棵树': (1648.0, 848.0),
#  '梨园': (1666.0, 867.0),
#  '临河里': (1687.0, 887.0),
#  '土桥': (1708.0, 907.0),
#  '大葆台': (528.0, 1045.0),
#  '稻田': (504.0, 1068.0),
#  '长阳': (482.0, 1089.0),
#  '篱笆房': (459.0, 1110.0),
#  '广阳城': (438.0, 1130.0),
#  '良乡大学城北': (417.0, 1151.0),
#  '良乡大学城': (390.0, 1176.0),
#  '良乡大学城西': (345.0, 1176.0),
#  '良乡南关': (292.0, 1176.0),
#  '苏庄': (240.0, 1176.0),
#  '生命科学园': (756.0, 369.0),
#  '巩华城': (795.0, 291.0),
#  '沙河': (795.0, 269.0),
#  '沙河高教园': (795.0, 248.0),
#  '南邵': (795.0, 227.0),
#  '北邵洼': (775.0, 190.0),
#  '昌平东关': (680.0, 190.0),
#  '昌平': (590.0, 190.0),
#  '十三陵景区': (522.0, 148.0),
#  '昌平西山口': (460.0, 140.0),
#  '肖村': (1065.0, 1000.0),
#  '小红门': (1082.0, 1017.0),
#  '旧宫': (1099.0, 1034.0),
#  '亦庄桥': (1118.0, 1052.0),
#  '亦庄文化园': (1134.0, 1067.0),
#  '万源街': (1151.0, 1084.0),
#  '荣京东街': (1171.0, 1103.0),
#  '荣昌东街': (1189.0, 1120.0),
#  '同济南路': (1214.0, 1128.0),
#  '经海路': (1257.0, 1128.0),
#  '次渠南': (1300.0, 1128.0),
#  '次渠': (1342.0, 1128.0),
#  '亦庄火车站': (1382.0, 1128.0),
#  '燕山': (-20.0, 1131.0),
#  '房山城关': (0.0, 1151.0),
#  '饶乐府': (25.0, 1176.0),
#  '马各庄': (55.0, 1176.0),
#  '大石河东': (85.0, 1176.0),
#  '星城': (115.0, 1176.0),
#  '阎村': (145.0, 1176.0),
#  '紫草坞': (175.0, 1176.0),
#  '石厂': (65.0, 845.0),
#  '小园': (103.0, 845.0),
#  '栗园庄': (140.0, 820.0),
#  '上岸': (140.0, 790.0),
#  '桥户营': (175.0, 760.0),
#  '四道桥': (210.0, 760.0),
#  '香山': (320.0, 450.0),
#  '植物园': (370.0, 450.0),
#  '万安': (380.0, 475.0),
#  '茶棚': (410.0, 500.0),
#  '颐和园西门': (460.0, 500.0),
#  'T3航站楼': (1570.0, 402.0),
#  'T2航站楼': (1489.0, 402.0),
#  '公主坟': (582.0, 783.0),
#  '军事博物馆': (621.0, 783.0),
#  '复兴门': (776.0, 783.0),
#  '西单': (855.0, 783.0),
#  '东单': (1058.0, 783.0),
#  '建国门': (1127.0, 783.0),
#  '国贸': (1229.0, 783.0),
#  '大望路': (1281.0, 783.0),
#  '四惠': (1327.0, 787.4),
#  '四惠东': (1366.0, 787.4),
#  '西直门': (776.0, 653.0),
#  '鼓楼大街': (943.0, 625.0),
#  '雍和宫': (1058.0, 625.0),
#  '东直门': (1127.0, 648.0),
#  '朝阳门': (1127.0, 731.0),
#  '崇文门': (1058.0, 834.0),
#  '宣武门': (855.0, 834.0),
#  '车公庄': (776.0, 703.0),
#  '西苑': (560.0, 403.0),
#  '海淀黄庄': (621.0, 536.0),
#  '国家图书馆': (621.0, 653.0),
#  '平安里': (855.0, 703.0),
#  '菜市口': (855.0, 860.0),
#  '北京南站': (855.0, 918.0),
#  '角门西': (855.0, 967.0),
#  '立水桥': (1058.0, 373.0),
#  '大屯路东': (1058.0, 474.0),
#  '惠新西街南口': (1058.0, 536.0),
#  '东四': (1058.0, 731.0),
#  '磁器口': (1058.0, 860.0),
#  '蒲黄榆': (1058.0, 918.0),
#  '宋家庄': (1058.0, 967.0),
#  '金安桥': (238.0, 753.0),
#  '慈寿寺': (527.0, 703.0),
#  '白石桥南': (621.0, 703.0),
#  '南锣鼓巷': (973.0, 703.0),
#  '呼家楼': (1229.0, 731.0),
#  '金台路': (1281.0, 731.0),
#  '北京西站': (621.0, 817.0),
#  '珠市口': (953.0, 860.0),
#  '九龙山': (1281.0, 860.0),
#  '朱辛庄': (788.0, 318.0),
#  '霍营': (907.0, 373.0),
#  '奥林匹克公园': (943.0, 474.0),
#  '北土城': (943.0, 536.0),
#  '永定门外': (953.0, 918.0),
#  '郭公庄': (541.0, 1019.0),
#  '七里庄': (541.0, 893.0),
#  '六里桥': (582.0, 862.0),
#  '西局': (582.0, 893.0),
#  '巴沟': (531.0, 543.0),
#  '知春路': (750.0, 536.0),
#  '芍药居': (1146.0, 536.0),
#  '三元桥': (1229.0, 581.0),
#  '十里河': (1229.0, 918.0),
#  '西二旗': (750.0, 416.0),
#  '望京西': (1146.0, 474.0),
#  '望京': (1212.0, 474.0),
#  '阎村东': (198.0, 1169.0),
#  '南八里庄': (1249.5, 921.5),
#  '红庙': (1281.0, 757.0)}

# %%
for k, v in p2p_map.items():
    print(k, v)
# Out:
# 15634746812298679584 苹果园-古城:12,2606
# 10581941666006768060 古城-八角游乐园:3,1921
# 9205493154023976953 八角游乐园-八宝山:3,1953
# 2571379525195920029 八宝山-玉泉路:2,1479
# -8174941494015639049 玉泉路-五棵松:3,1810
# 4047896121577591337 五棵松-万寿路:3,1778
# 5382317631213376997 万寿路-公主坟:2,1313
# 1822710768132213056 公主坟-军事博物馆:3,1172
# 10656820929176224179 军事博物馆-木樨地:2,1166
# 5222737099264206697 木樨地-南礼士路:2,1291
# 1750530730406221502 南礼士路-复兴门:6,424
# -4489018944684719387 复兴门-西单:2,1590
# -6768101224868043328 西单-天安门西:2,1217
# 164305839437990901 天安门西-天安门东:2,925
# -6263078434659505687 天安门东-王府井:2,852
# -7204676038281686437 王府井-东单:2,774
# 1210077908163319000 东单-建国门:3,1230
# -1009021763871017472 建国门-永安里:2,1377
# -10175432924096774109 永安里-国贸:2,790
# -13402303544869974491 国贸-大望路:3,1385
# -3969549080577866940 大望路-四惠:3,1673
# 1260623955997700111 四惠-四惠东:2,1715
# -6839563681823179242 西直门-积水潭:25,1899
# 8329803995286961753 积水潭-鼓楼大街:3,1766
# 12832913172000416412 鼓楼大街-安定门:3,1237
# -2195891589298548718 安定门-雍和宫:1,794
# -14119305966917640663 雍和宫-东直门:4,2228
# 1696180358934735939 东直门-东四十条:2,824
# 9434382379292788586 东四十条-朝阳门:2,1027
# 3947575489338888634 朝阳门-建国门:3,1763
# 7925296196728237376 建国门-北京站:2,945
# 10821860670432989238 北京站-崇文门:13,1023
# 2999372247965203229 崇文门-前门:3,1634
# -1480326488577584318 前门-和平门:2,1171
# -3817006476194238233 和平门-宣武门:2,851
# 3670312080292807758 宣武门-长椿街:2,929
# 9762962978466748308 长椿街-复兴门:2,1234
# -6007977619098236364 复兴门-阜成门:3,1832
# -7758764684366044446 阜成门-车公庄:2,960
# 2635118857711599822 天宫院-生物医药基地:2,1811
# 4895807341067875996 生物医药基地-义和庄:3,2918
# 12519642958778936804 义和庄-黄村火车站:3,2035
# 6454217257575176164 黄村火车站-黄村西大街:2,987
# -1300442482870240405 黄村西大街-清源路:2,1214
# 7151247334558375780 清源路-枣园:2,1200
# 15333667833289701380 枣园-高米店南:2,1096
# 13576046197296209220 高米店南-高米店北:2,1128
# 6271690523538393865 高米店北-西红门:3,1810
# -10135101427250660043 西红门-新宫:6,5102
# -17466137903208288524 新宫-公益西桥:47,2798
# -12390043299366894178 公益西桥-角门西:1,989
# -10620545406617631393 角门西-马家堡:2,827
# 1532985118009288563 马家堡-北京南站:2,1480
# 3061811202943530034 北京南站-陶然亭:3,1643
# -8904772038082048078 陶然亭-菜市口:2,1200
# -7744280227549926618 菜市口-宣武门:3,1152
# -10581669842858659937 宣武门-西单:2,815
# -6777610197018678578 西单-灵境胡同:1,1011
# -7898439709733677902 灵境胡同-西四:2,869
# -3387850792368911961 西四-平安里:2,1100
# 6120686395610463177 平安里-新街口:2,1100
# -6862266228965811180 新街口-西直门:3,1025
# -6650657276525062578 西直门-动物园:2,1441
# 1724600306531225374 动物园-国家图书馆:2,1517
# -1718656756144224176 国家图书馆-魏公村:3,1658
# -2924922689628721053 魏公村-人民大学:2,1051
# -613766714232827435 人民大学-海淀黄庄:3,1063
# 1875753637316944954 海淀黄庄-中关村:1,900
# 7859729808265947185 中关村-北京大学东门:2,887
# 4132357829344094430 北京大学东门-圆明园:2,1295
# -1665893422227231750 圆明园-西苑:3,1672
# -2954740681044609323 西苑-北宫门:2,1251
# -2164867780845587932 北宫门-安河桥北:None,1363
# -10282448771194546075 宋家庄-刘家窑:2,1670
# -1686593968995078365 刘家窑-蒲黄榆:2,905
# 525484479923374218 蒲黄榆-天坛东门:3,1900
# -1063432292316005605 天坛东门-磁器口:2,1183
# 5704071923783645066 磁器口-崇文门:2,876
# 4106642381868070862 崇文门-东单:2,821
# -2268817712897865048 东单-灯市口:2,945
# -5946731386574108545 灯市口-东四:2,848
# -13268931415438700156 东四-张自忠路:2,1016
# -15773889936000612865 张自忠路-北新桥:2,791
# -15301473721973313856 北新桥-雍和宫:2,866
# -2070043459075941116 雍和宫-和平里北街:2,1151
# 13880280715775495889 和平里北街-和平西桥:2,1059
# 4042087271724348321 和平西桥-惠新西街南口:3,1025
# -10024502280016887332 惠新西街南口-惠新西街北口:2,1122
# 277903451274851353 惠新西街北口-大屯路东:2,1838
# 13750383717536233642 大屯路东-北苑路北:4,3000
# 112316082101120468 北苑路北-立水桥南:2,1286
# -14078782795715382110 立水桥南-立水桥:3,1305
# -15728431060553871317 立水桥-天通苑南:3,1544
# -14365235170483177762 天通苑南-天通苑:1,965
# -11439761875900361621 天通苑-天通苑北:2,939
# 14575907789610417156 金安桥-苹果园:None,None
# 2344220755770427933 苹果园-杨庄:None,None
# -5597924931175984842 杨庄-西黄村:3,None
# 4255014994645339123 西黄村-廖公庄:2,None
# 13175376047125611383 廖公庄-田村:3,None
# 5915015795687056519 田村-海淀五路居:3,None
# 1909040168126716998 海淀五路居-慈寿寺:57,1508
# 195527255552704947 慈寿寺-花园桥:3,1431
# -2682643522003323283 花园桥-白石桥南:2,1166
# 4115729543329514266 白石桥南-车公庄西:3,1664
# 2213062227371626557 车公庄西-车公庄:1,887
# 4621701892416551762 车公庄-平安里:3,1443
# 6038414086530328867 平安里-北海北:3,1321
# -1974877734165130375 北海北-南锣鼓巷:2,1349
# -7967417313341761897 南锣鼓巷-东四:3,1937
# -2087326353155958773 东四-朝阳门:3,1399
# 6481509067297383064 朝阳门-东大桥:3,1668
# 12800880514003137774 东大桥-呼家楼:2,845
# 11976971591912092577 呼家楼-金台路:3,1450
# 8944644940073160889 金台路-十里堡:3,2036
# 5531303963865900100 十里堡-青年路:2,1282
# -493254931694086328 青年路-褡裢坡:4,3999
# 3906016452911323629 褡裢坡-黄渠:2,1238
# -1361162918289095830 黄渠-常营:3,1854
# -5956196539880951405 常营-草房:2,1405
# 5497231944487739347 草房-物资学院路:11,2115
# 13703297331093360953 物资学院路-通州北关:3,2557
# 15740202677377922031 通州北关-通运门:None,1468
# 3150256885005751297 通运门-北运河西:None,1543
# -12479994558247106790 北运河西-北运河东:2,1599
# -4655991962803813070 北运河东-郝家府:2,929
# 2071740884195779268 郝家府-东夏园:2,1346
# -995054025607943414 东夏园-潞城:2,1194
# 4237283502302510599 北京西站-湾子:2,935
# 4389421563151990417 湾子-达官营:2,734
# 13393962780139399414 达官营-广安门内:2,1874
# 3418939967186852804 广安门内-菜市口:3,1374
# -177650168484483781 菜市口-虎坊桥:2,885
# 3957366211273035653 虎坊桥-珠市口:2,1205
# 6154776509707197417 珠市口-桥湾:2,869
# 6770609517240372347 桥湾-磁器口:2,1016
# 5299795265431518958 磁器口-广渠门内:3,1138
# 8317413436915007001 广渠门内-广渠门外:2,1332
# 8908377567203950253 广渠门外-双井:None,1241
# 10170118521581567848 双井-九龙山:None,1311
# 11069447082034692956 九龙山-大郊亭:2,781
# 8222109446164982985 大郊亭-百子湾:2,865
# 243854766227903072 百子湾-化工:2,903
# 1465502567968419382 化工-南楼梓庄:2,1464
# 10617897811876572848 南楼梓庄-欢乐谷景区:2,906
# 8879865103405944631 欢乐谷景区-垡头:3,1679
# -739988962350875139 垡头-双合:2,1304
# 3384226952805084193 双合-焦化厂:2,1021
# 11076618947252872560 朱辛庄-育知路:3,2318
# 12409493833223170324 育知路-平西府:3,1985
# -734895039482487733 平西府-回龙观东大街:36,2056
# -9358797462985771273 回龙观东大街-霍营:2,1114
# 3729199872555314824 霍营-育新:3,1894
# 11341469074201017585 育新-西小口:3,1543
# -56274747579972543 西小口-永泰庄:2,1041
# -3004514796285476826 永泰庄-林萃桥:4,2553
# -6876576998739543172 林萃桥-森林公园南门:4,2555
# -12869069966341604595 森林公园南门-奥林匹克公园:2,1016
# 1024799118289031681 奥林匹克公园-奥体中心:3,1667
# 7793400108711881213 奥体中心-北土城:2,900
# 9714326226159591443 北土城-安华桥:2,1018
# 12216128704105842351 安华桥-安德里北街:3,1274
# 11613036597381157368 安德里北街-鼓楼大街:2,1083
# 6188998141314362504 鼓楼大街-什刹海:2,1188
# -4010708731914963376 什刹海-南锣鼓巷:3,902
# -3826887761492873049 南锣鼓巷-中国美术馆:3,None
# 705070148011758460 瀛海-德茂:2,None
# -3257101090625669601 德茂-五福堂:4,None
# -9268385802959199225 五福堂-火箭万源:2,None
# -10044842386554176227 火箭万源-东高地:3,None
# -15479541904303209058 东高地-和义:3,None
# -11949761965576683180 和义-大红门南:3,None
# 1014106245275329538 大红门南-大红门:None,None
# 11015968611514093885 大红门-海户屯:None,None
# 10146144678791539960 海户屯-木樨园:2,None
# 7699154178204243758 木樨园-永定门外:2,None
# 10822065415133011326 永定门外-天桥:3,None
# 7654414808399655923 天桥-珠市口:2,None
# -4727618937078546478 郭公庄-丰台科技园:2,1347
# -1424881869923593615 丰台科技园-科怡路:2,788
# -1822874281494519064 科怡路-丰台南路:2,980
# 7207162947237673417 丰台南路-丰台东大街:2,1585
# -221184666279723366 丰台东大街-七里庄:2,1325
# -16167826867328134084 七里庄-六里桥:4,1778
# -4265477958742270297 六里桥-六里桥东:3,1309
# 9381658936251135820 六里桥东-北京西站:3,1170
# 11205378690391766614 北京西站-军事博物馆:3,1398
# -3782262806597862121 军事博物馆-白堆子:4,1912
# -6664505823572468384 白堆子-白石桥南:2,943
# 1916674166854453066 白石桥南-国家图书馆:2,1096
# 4068686291844467293 巴沟-苏州街:2,1110
# -438234060912511198 苏州街-海淀黄庄:2,950
# 8416899949640808213 海淀黄庄-知春里:2,975
# 425007281466724050 知春里-知春路:2,1058
# -6105589057531415136 知春路-西土城:2,1101
# 9826768361771675397 西土城-牡丹园:2,1330
# 5501641209257475201 牡丹园-健德门:2,973
# -714198735742147194 健德门-北土城:2,1100
# 10932533366786284170 北土城-安贞门:2,1020
# 4941867105523254156 安贞门-惠新西街南口:3,982
# -2963621561871290031 惠新西街南口-芍药居:3,1712
# 2562401352923263022 芍药居-太阳宫:2,1003
# 1410971018227961447 太阳宫-三元桥:2,1759
# 5045343834187859810 三元桥-亮马桥:3,1506
# -1062679283447073595 亮马桥-农业展览馆:2,914
# -8134577051908335015 农业展览馆-团结湖:2,853
# 7208821354127298396 团结湖-呼家楼:2,1149
# 4638176767701357380 呼家楼-金台夕照:2,734
# -11228115251587119691 金台夕照-国贸:2,835
# -2516093137602264721 国贸-双井:2,1759
# 10833370700611285438 双井-劲松:2,1006
# 7830270283801460176 劲松-潘家园:2,1021
# 5460593645796879996 潘家园-十里河:2,1097
# 8880603681759827072 十里河-分钟寺:3,1804
# -1624924704552712480 分钟寺-成寿寺:2,1058
# -12891582926210520893 成寿寺-宋家庄:13,1677
# -8280925080548222245 宋家庄-石榴庄:2,1269
# 2695224637962619354 石榴庄-大红门:2,1244
# 8830586915899710821 大红门-角门东:2,1130
# -76421443543079099 角门东-角门西:3,1254
# -3667715937861046569 角门西-草桥:3,1688
# 6758578927370914733 草桥-纪家庙:2,1547
# 7502701244567378254 纪家庙-首经贸:3,1143
# -1613110555646965009 首经贸-丰台站:3,1717
# -6324885793790444120 丰台站-泥洼:2,954
# -594942030889388758 泥洼-西局:2,749
# -4424522549978532998 西局-六里桥:3,1584
# -2247484497572552980 六里桥-莲花桥:4,2392
# 2016984475161299579 莲花桥-公主坟:2,1016
# -7614100752321097756 公主坟-西钓鱼台:3,2386
# 777854068111036029 西钓鱼台-慈寿寺:2,1214
# 10773427933974497648 慈寿寺-车道沟:86,1590
# 14519009846000173447 车道沟-长春桥:2,1205
# 17309588030461138855 长春桥-火器营:2,961
# -7272954494808535013 西直门-大钟寺:4,2839
# -5676186900349855566 大钟寺-知春路:2,1206
# -11718394179163944332 知春路-五道口:3,1829
# 2235731949708913290 五道口-上地:6,4866
# -601383974081018758 上地-西二旗:4,2538
# -924415523581934793 西二旗-龙泽:5,3623
# 11048178819756737000 龙泽-回龙观:3,1423
# 1693464538927276964 回龙观-霍营:3,2110
# -10192591806069964194 霍营-立水桥:56,4785
# -16232253037350017100 立水桥-北苑:4,2272
# -6454664777125829233 北苑-望京西:7,6720
# 2797026818220037193 望京西-芍药居:3,2152
# 4269236067710214391 芍药居-光熙门:3,1110
# -2218666084227484438 光熙门-柳芳:2,1135
# -11662592777599540839 柳芳-东直门:2,1769
# -537550299705473228 张郭庄-园博园:1,1345
# 5940145301084548953 园博园-大瓦窑:5,4073
# 10195975834304605691 大瓦窑-郭庄子:3,1236
# 6004843038311177919 郭庄子-大井:3,2044
# -8989962291474238021 大井-七里庄:3,1579
# -5490095180120463202 七里庄-西局:1,845
# 11815500276110927719 北京南站-永定门外:3,None
# -2905659118598899191 永定门外-景泰:2,1119
# -3868559945559699841 景泰-蒲黄榆:3,1025
# 1883180848602548574 蒲黄榆-方庄:2,1486
# 2867198743249411799 方庄-十里河:3,1618
# -223825347247488637 十里河-北工大西门:4,None
# -9331944635923539170 北工大西门-平乐园:2,1128
# -207876672752838349 平乐园-九龙山:2,897
# -716091885686141922 九龙山-大望路:3,1780
# -2525867728776768621 大望路-金台路:3,None
# -1439742049334984121 金台路-朝阳公园:2,1085
# -2805615415708100989 朝阳公园-枣营:3,1221
# -2599242731958440637 枣营-东风北桥:3,2173
# 3412367094837233578 东风北桥-将台:2,1600
# 4438240616852698796 将台-望京南:4,None
# 3903191027289702932 望京南-阜通:2,1168
# 3269706465603761853 阜通-望京:2,903
# -9700027320756645807 望京-东湖渠:3,1283
# -9871188164595386110 东湖渠-来广营:2,1100
# -13536679570210192952 来广营-善各庄:2,1364
# 2352902614288296708 俸伯-顺义:3,2441
# 4707741001140054723 顺义-石门:2,1331
# 1537985568804612101 石门-南法信:4,2712
# 100568446410076525 南法信-后沙峪:5,4576
# 535764603759805510 后沙峪-花梨坎:3,3354
# -4735606670239200853 花梨坎-国展:3,1615
# -6940980764368048782 国展-孙河:4,3386
# 1744874684164573573 孙河-马泉营:47,3309
# 359448174392834134 马泉营-崔各庄:3,2008
# -9894617499815845613 崔各庄-望京东:3,2295
# -7426649517792007410 望京东-望京:3,1652
# -1936980225242456583 望京-望京西:3,1758
# 7868866008596240443 望京西-关庄:4,2071
# 12410623359796651904 关庄-大屯路东:3,1087
# -290375363463010633 大屯路东-安立路:1,938
# -11370715823914568836 安立路-奥林匹克公园:3,1368
# 4898220669777451465 奥林匹克公园-北沙滩:3,1999
# 5684656673566142156 北沙滩-六道口:2,1337
# -12391327235652947703 六道口-清华东路西口:2,1144
# -2123631382372525145 西苑-农大南路:3,None
# -10655247338488740481 农大南路-马连洼:3,None
# -4624487815263403874 马连洼-西北旺:3,None
# -4999082367934212699 西北旺-永丰南:4,None
# -13189403777322928984 永丰南-永丰:3,None
# -9706712176649083727 永丰-屯佃:4,None
# -6588775880929157445 屯佃-稻香湖路:3,None
# -2459607695312604368 稻香湖路-温阳路:4,None
# 6104448651036535204 温阳路-北安河:3,None
# -3073818134183662645 四惠东-高碑店:3,1375
# 6635201908592353030 高碑店-传媒大学:3,2002
# 2414497448927156866 传媒大学-双桥:3,1894
# -14253063565041547441 双桥-管庄:2,1912
# -6013001784014918574 管庄-八里桥:3,1763
# 8073975150969207072 八里桥-通州北苑:3,1700
# 15519466642603461771 通州北苑-果园:3,1465
# 1592816780891575536 果园-九棵树:2,990
# -14854002394645414340 九棵树-梨园:2,1225
# -5810597686506969730 梨园-临河里:3,1257
# 177767063581852711 临河里-土桥:1,776
# 11930515882320076437 昌平西山口-十三陵景区:2,1213
# 4364724843287545941 十三陵景区-昌平:4,3508
# -5232858053967379546 昌平-昌平东关:3,2433
# 3892407332245900645 昌平东关-北邵洼:2,1683
# -1666492043413486016 北邵洼-南邵:3,1958
# -16737494059566256119 南邵-沙河高教园:5,5357
# -99241653168308384 沙河高教园-沙河:3,1964
# 13589290475981999098 沙河-巩华城:3,2025
# 9832965276096005784 巩华城-朱辛庄:4,3799
# 5879258394431165854 朱辛庄-生命科学园:15,2367
# -6065776107078154627 生命科学园-西二旗:5,5440
# -14294106416289349933 宋家庄-肖村:3,2631
# -15659328394039458194 肖村-小红门:2,1275
# -7439190350256924328 小红门-旧宫:4,2366
# 3495055016231681747 旧宫-亦庄桥:2,1982
# 5161520451819667746 亦庄桥-亦庄文化园:2,993
# 2440237318586575152 亦庄文化园-万源街:3,1728
# -7659457582421318106 万源街-荣京东街:2,1090
# -5325985437709582519 荣京东街-荣昌东街:2,1355
# 8828389857034992421 荣昌东街-同济南路:4,2337
# 14495715002967558102 同济南路-经海路:3,2301
# 12374391563838452885 经海路-次渠南:2,2055
# 11453451479795484478 次渠南-次渠:3,1281
# 13317472601091482740 次渠-亦庄火车站:3,None
# -11902897834859570296 郭公庄-大葆台:2,1405
# -10350822254532244912 大葆台-稻田:6,6466
# -972082112071296220 稻田-长阳:5,4041
# 5878334378035365560 长阳-篱笆房:3,2150
# 1853768343172236612 篱笆房-广阳城:3,1474
# -149727041913691218 广阳城-良乡大学城北:3,2003
# -1037837756203153948 良乡大学城北-良乡大学城:2,1188
# -6795571034452346479 良乡大学城-良乡大学城西:3,1738
# -9493359797867241303 良乡大学城西-良乡南关:2,1332
# -8041760505071467170 良乡南关-苏庄:3,1330
# -8845965772559990748 苏庄-阎村东:4,None
# 4131833114330596936 金安桥-四道桥:4,None
# 1843782911840049231 四道桥-桥户营:2,None
# 4787654030622236512 桥户营-上岸:3,None
# 7105129830970127217 上岸-栗园庄:2,None
# 3319480033362918420 栗园庄-小园:3,None
# 3321638859034061674 小园-石厂:2,None
# 110398370981538451 阎村东-紫草坞:2,None
# 15522518121633895106 紫草坞-阎村:2,None
# 14814849371811609023 阎村-星城:3,None
# 7895855246464166020 星城-大石河东:3,None
# 1696128604770805135 大石河东-马各庄:3,None
# 4974226372539023461 马各庄-饶乐府:2,None
# 855057056751366644 饶乐府-房山城关:3,None
# -3884956934068972484 房山城关-燕山:2,None
# -8361250732159722595 西直门-车公庄:None,909
# 13868580746033629693 火器营-巴沟:None,1495
# 7787947380607860785 北京南站-陶然桥:None,887
# 3124031126073157510 陶然桥-永定门外:None,1063
# 11730084818021298122 十里河-南八里庄:None,1147
# 4312441313825459891 南八里庄-北工大西门:None,1276
# 2597968231251809527 大望路-红庙:None,708
# 12110951348745399524 红庙-金台路:None,894
# 5734130083177197974 将台-高家园:None,1171
# -6106217609532039300 高家园-望京南:None,676
# -6326120960357143585 东直门-三元桥:None,2999
# -1839848136588597734 三元桥-T3航站楼:None,18329
# -8631658719142839321 T3航站楼-T2航站楼:None,7239
# -8295733364248277821 T2航站楼-三元桥:None,20619

# %%
connection_map
# Out:
# {'苹果园': {'古城', '杨庄', '金安桥'},
#  '古城': {'八角游乐园', '苹果园'},
#  '八角游乐园': {'八宝山', '古城'},
#  '八宝山': {'八角游乐园', '玉泉路'},
#  '玉泉路': {'五棵松', '八宝山'},
#  '五棵松': {'万寿路', '玉泉路'},
#  '万寿路': {'五棵松', '公主坟'},
#  '公主坟': {'万寿路', '军事博物馆', '莲花桥', '西钓鱼台'},
#  '军事博物馆': {'公主坟', '北京西站', '木樨地', '白堆子'},
#  '木樨地': {'军事博物馆', '南礼士路'},
#  '南礼士路': {'复兴门', '木樨地'},
#  '复兴门': {'南礼士路', '西单', '长椿街', '阜成门'},
#  '西单': {'复兴门', '天安门西', '宣武门', '灵境胡同'},
#  '天安门西': {'天安门东', '西单'},
#  '天安门东': {'天安门西', '王府井'},
#  '王府井': {'东单', '天安门东'},
#  '东单': {'崇文门', '建国门', '灯市口', '王府井'},
#  '建国门': {'东单', '北京站', '朝阳门', '永安里'},
#  '永安里': {'国贸', '建国门'},
#  '国贸': {'双井', '大望路', '永安里', '金台夕照'},
#  '大望路': {'九龙山', '四惠', '国贸', '红庙', '金台路'},
#  '四惠': {'四惠东', '大望路'},
#  '四惠东': {'四惠', '高碑店'},
#  '西直门': {'动物园', '大钟寺', '新街口', '积水潭', '车公庄'},
#  '积水潭': {'西直门', '鼓楼大街'},
#  '鼓楼大街': {'什刹海', '安定门', '安德里北街', '积水潭'},
#  '安定门': {'雍和宫', '鼓楼大街'},
#  '雍和宫': {'东直门', '北新桥', '和平里北街', '安定门'},
#  '东直门': {'三元桥', '东四十条', '柳芳', '雍和宫'},
#  '东四十条': {'东直门', '朝阳门'},
#  '朝阳门': {'东四', '东四十条', '东大桥', '建国门'},
#  '北京站': {'崇文门', '建国门'},
#  '崇文门': {'东单', '前门', '北京站', '磁器口'},
#  '前门': {'和平门', '崇文门'},
#  '和平门': {'前门', '宣武门'},
#  '宣武门': {'和平门', '菜市口', '西单', '长椿街'},
#  '长椿街': {'复兴门', '宣武门'},
#  '阜成门': {'复兴门', '车公庄'},
#  '车公庄': {'平安里', '西直门', '车公庄西', '阜成门'},
#  '天宫院': {'生物医药基地'},
#  '生物医药基地': {'义和庄', '天宫院'},
#  '义和庄': {'生物医药基地', '黄村火车站'},
#  '黄村火车站': {'义和庄', '黄村西大街'},
#  '黄村西大街': {'清源路', '黄村火车站'},
#  '清源路': {'枣园', '黄村西大街'},
#  '枣园': {'清源路', '高米店南'},
#  '高米店南': {'枣园', '高米店北'},
#  '高米店北': {'西红门', '高米店南'},
#  '西红门': {'新宫', '高米店北'},
#  '新宫': {'公益西桥', '西红门'},
#  '公益西桥': {'新宫', '角门西'},
#  '角门西': {'公益西桥', '草桥', '角门东', '马家堡'},
#  '马家堡': {'北京南站', '角门西'},
#  '北京南站': {'永定门外', '陶然亭', '陶然桥', '马家堡'},
#  '陶然亭': {'北京南站', '菜市口'},
#  '菜市口': {'宣武门', '广安门内', '虎坊桥', '陶然亭'},
#  '灵境胡同': {'西单', '西四'},
#  '西四': {'平安里', '灵境胡同'},
#  '平安里': {'北海北', '新街口', '西四', '车公庄'},
#  '新街口': {'平安里', '西直门'},
#  '动物园': {'国家图书馆', '西直门'},
#  '国家图书馆': {'动物园', '白石桥南', '魏公村'},
#  '魏公村': {'人民大学', '国家图书馆'},
#  '人民大学': {'海淀黄庄', '魏公村'},
#  '海淀黄庄': {'中关村', '人民大学', '知春里', '苏州街'},
#  '中关村': {'北京大学东门', '海淀黄庄'},
#  '北京大学东门': {'中关村', '圆明园'},
#  '圆明园': {'北京大学东门', '西苑'},
#  '西苑': {'农大南路', '北宫门', '圆明园'},
#  '北宫门': {'安河桥北', '西苑'},
#  '安河桥北': {'北宫门'},
#  '宋家庄': {'刘家窑', '成寿寺', '石榴庄', '肖村'},
#  '刘家窑': {'宋家庄', '蒲黄榆'},
#  '蒲黄榆': {'刘家窑', '天坛东门', '方庄', '景泰'},
#  '天坛东门': {'磁器口', '蒲黄榆'},
#  '磁器口': {'天坛东门', '崇文门', '广渠门内', '桥湾'},
#  '灯市口': {'东单', '东四'},
#  '东四': {'南锣鼓巷', '张自忠路', '朝阳门', '灯市口'},
#  '张自忠路': {'东四', '北新桥'},
#  '北新桥': {'张自忠路', '雍和宫'},
#  '和平里北街': {'和平西桥', '雍和宫'},
#  '和平西桥': {'和平里北街', '惠新西街南口'},
#  '惠新西街南口': {'和平西桥', '安贞门', '惠新西街北口', '芍药居'},
#  '惠新西街北口': {'大屯路东', '惠新西街南口'},
#  '大屯路东': {'关庄', '北苑路北', '安立路', '惠新西街北口'},
#  '北苑路北': {'大屯路东', '立水桥南'},
#  '立水桥南': {'北苑路北', '立水桥'},
#  '立水桥': {'北苑', '天通苑南', '立水桥南', '霍营'},
#  '天通苑南': {'天通苑', '立水桥'},
#  '天通苑': {'天通苑北', '天通苑南'},
#  '天通苑北': {'天通苑'},
#  '金安桥': {'四道桥', '苹果园'},
#  '杨庄': {'苹果园', '西黄村'},
#  '西黄村': {'廖公庄', '杨庄'},
#  '廖公庄': {'田村', '西黄村'},
#  '田村': {'廖公庄', '海淀五路居'},
#  '海淀五路居': {'慈寿寺', '田村'},
#  '慈寿寺': {'海淀五路居', '花园桥', '西钓鱼台', '车道沟'},
#  '花园桥': {'慈寿寺', '白石桥南'},
#  '白石桥南': {'国家图书馆', '白堆子', '花园桥', '车公庄西'},
#  '车公庄西': {'白石桥南', '车公庄'},
#  '北海北': {'南锣鼓巷', '平安里'},
#  '南锣鼓巷': {'东四', '中国美术馆', '什刹海', '北海北'},
#  '东大桥': {'呼家楼', '朝阳门'},
#  '呼家楼': {'东大桥', '团结湖', '金台夕照', '金台路'},
#  '金台路': {'十里堡', '呼家楼', '大望路', '朝阳公园', '红庙'},
#  '十里堡': {'金台路', '青年路'},
#  '青年路': {'十里堡', '褡裢坡'},
#  '褡裢坡': {'青年路', '黄渠'},
#  '黄渠': {'常营', '褡裢坡'},
#  '常营': {'草房', '黄渠'},
#  '草房': {'常营', '物资学院路'},
#  '物资学院路': {'草房', '通州北关'},
#  '通州北关': {'物资学院路', '通运门'},
#  '通运门': {'北运河西', '通州北关'},
#  '北运河西': {'北运河东', '通运门'},
#  '北运河东': {'北运河西', '郝家府'},
#  '郝家府': {'东夏园', '北运河东'},
#  '东夏园': {'潞城', '郝家府'},
#  '潞城': {'东夏园'},
#  '北京西站': {'六里桥东', '军事博物馆', '湾子'},
#  '湾子': {'北京西站', '达官营'},
#  '达官营': {'广安门内', '湾子'},
#  '广安门内': {'菜市口', '达官营'},
#  '虎坊桥': {'珠市口', '菜市口'},
#  '珠市口': {'天桥', '桥湾', '虎坊桥'},
#  '桥湾': {'珠市口', '磁器口'},
#  '广渠门内': {'广渠门外', '磁器口'},
#  '广渠门外': {'双井', '广渠门内'},
#  '双井': {'九龙山', '劲松', '国贸', '广渠门外'},
#  '九龙山': {'双井', '大望路', '大郊亭', '平乐园'},
#  '大郊亭': {'九龙山', '百子湾'},
#  '百子湾': {'化工', '大郊亭'},
#  '化工': {'南楼梓庄', '百子湾'},
#  '南楼梓庄': {'化工', '欢乐谷景区'},
#  '欢乐谷景区': {'南楼梓庄', '垡头'},
#  '垡头': {'双合', '欢乐谷景区'},
#  '双合': {'垡头', '焦化厂'},
#  '焦化厂': {'双合'},
#  '朱辛庄': {'巩华城', '生命科学园', '育知路'},
#  '育知路': {'平西府', '朱辛庄'},
#  '平西府': {'回龙观东大街', '育知路'},
#  '回龙观东大街': {'平西府', '霍营'},
#  '霍营': {'回龙观', '回龙观东大街', '立水桥', '育新'},
#  '育新': {'西小口', '霍营'},
#  '西小口': {'永泰庄', '育新'},
#  '永泰庄': {'林萃桥', '西小口'},
#  '林萃桥': {'森林公园南门', '永泰庄'},
#  '森林公园南门': {'奥林匹克公园', '林萃桥'},
#  '奥林匹克公园': {'北沙滩', '奥体中心', '安立路', '森林公园南门'},
#  '奥体中心': {'北土城', '奥林匹克公园'},
#  '北土城': {'健德门', '奥体中心', '安华桥', '安贞门'},
#  '安华桥': {'北土城', '安德里北街'},
#  '安德里北街': {'安华桥', '鼓楼大街'},
#  '什刹海': {'南锣鼓巷', '鼓楼大街'},
#  '中国美术馆': {'南锣鼓巷'},
#  '瀛海': {'德茂'},
#  '德茂': {'五福堂', '瀛海'},
#  '五福堂': {'德茂', '火箭万源'},
#  '火箭万源': {'东高地', '五福堂'},
#  '东高地': {'和义', '火箭万源'},
#  '和义': {'东高地', '大红门南'},
#  '大红门南': {'和义', '大红门'},
#  '大红门': {'大红门南', '海户屯', '石榴庄', '角门东'},
#  '海户屯': {'大红门', '木樨园'},
#  '木樨园': {'永定门外', '海户屯'},
#  '永定门外': {'北京南站', '天桥', '景泰', '木樨园', '陶然桥'},
#  '天桥': {'永定门外', '珠市口'},
#  '郭公庄': {'丰台科技园', '大葆台'},
#  '丰台科技园': {'科怡路', '郭公庄'},
#  '科怡路': {'丰台南路', '丰台科技园'},
#  '丰台南路': {'丰台东大街', '科怡路'},
#  '丰台东大街': {'七里庄', '丰台南路'},
#  '七里庄': {'丰台东大街', '六里桥', '大井', '西局'},
#  '六里桥': {'七里庄', '六里桥东', '莲花桥', '西局'},
#  '六里桥东': {'六里桥', '北京西站'},
#  '白堆子': {'军事博物馆', '白石桥南'},
#  '巴沟': {'火器营', '苏州街'},
#  '苏州街': {'巴沟', '海淀黄庄'},
#  '知春里': {'海淀黄庄', '知春路'},
#  '知春路': {'五道口', '大钟寺', '知春里', '西土城'},
#  '西土城': {'牡丹园', '知春路'},
#  '牡丹园': {'健德门', '西土城'},
#  '健德门': {'北土城', '牡丹园'},
#  '安贞门': {'北土城', '惠新西街南口'},
#  '芍药居': {'光熙门', '太阳宫', '惠新西街南口', '望京西'},
#  '太阳宫': {'三元桥', '芍药居'},
#  '三元桥': {'T2航站楼', 'T3航站楼', '东直门', '亮马桥', '太阳宫'},
#  '亮马桥': {'三元桥', '农业展览馆'},
#  '农业展览馆': {'亮马桥', '团结湖'},
#  '团结湖': {'农业展览馆', '呼家楼'},
#  '金台夕照': {'呼家楼', '国贸'},
#  '劲松': {'双井', '潘家园'},
#  '潘家园': {'劲松', '十里河'},
#  '十里河': {'分钟寺', '北工大西门', '南八里庄', '方庄', '潘家园'},
#  '分钟寺': {'十里河', '成寿寺'},
#  '成寿寺': {'分钟寺', '宋家庄'},
#  '石榴庄': {'大红门', '宋家庄'},
#  '角门东': {'大红门', '角门西'},
#  '草桥': {'纪家庙', '角门西'},
#  '纪家庙': {'草桥', '首经贸'},
#  '首经贸': {'丰台站', '纪家庙'},
#  '丰台站': {'泥洼', '首经贸'},
#  '泥洼': {'丰台站', '西局'},
#  '西局': {'七里庄', '六里桥', '泥洼'},
#  '莲花桥': {'公主坟', '六里桥'},
#  '西钓鱼台': {'公主坟', '慈寿寺'},
#  '车道沟': {'慈寿寺', '长春桥'},
#  '长春桥': {'火器营', '车道沟'},
#  '火器营': {'巴沟', '长春桥'},
#  '大钟寺': {'知春路', '西直门'},
#  '五道口': {'上地', '知春路'},
#  '上地': {'五道口', '西二旗'},
#  '西二旗': {'上地', '生命科学园', '龙泽'},
#  '龙泽': {'回龙观', '西二旗'},
#  '回龙观': {'霍营', '龙泽'},
#  '北苑': {'望京西', '立水桥'},
#  '望京西': {'关庄', '北苑', '望京', '芍药居'},
#  '光熙门': {'柳芳', '芍药居'},
#  '柳芳': {'东直门', '光熙门'},
#  '张郭庄': {'园博园'},
#  '园博园': {'大瓦窑', '张郭庄'},
#  '大瓦窑': {'园博园', '郭庄子'},
#  '郭庄子': {'大井', '大瓦窑'},
#  '大井': {'七里庄', '郭庄子'},
#  '景泰': {'永定门外', '蒲黄榆'},
#  '方庄': {'十里河', '蒲黄榆'},
#  '北工大西门': {'十里河', '南八里庄', '平乐园'},
#  '平乐园': {'九龙山', '北工大西门'},
#  '朝阳公园': {'枣营', '金台路'},
#  '枣营': {'东风北桥', '朝阳公园'},
#  '东风北桥': {'将台', '枣营'},
#  '将台': {'东风北桥', '望京南', '高家园'},
#  '望京南': {'将台', '阜通', '高家园'},
#  '阜通': {'望京', '望京南'},
#  '望京': {'东湖渠', '望京东', '望京西', '阜通'},
#  '东湖渠': {'望京', '来广营'},
#  '来广营': {'东湖渠', '善各庄'},
#  '善各庄': {'来广营'},
#  '俸伯': {'顺义'},
#  '顺义': {'俸伯', '石门'},
#  '石门': {'南法信', '顺义'},
#  '南法信': {'后沙峪', '石门'},
#  '后沙峪': {'南法信', '花梨坎'},
#  '花梨坎': {'后沙峪', '国展'},
#  '国展': {'孙河', '花梨坎'},
#  '孙河': {'国展', '马泉营'},
#  '马泉营': {'孙河', '崔各庄'},
#  '崔各庄': {'望京东', '马泉营'},
#  '望京东': {'崔各庄', '望京'},
#  '关庄': {'大屯路东', '望京西'},
#  '安立路': {'大屯路东', '奥林匹克公园'},
#  '北沙滩': {'六道口', '奥林匹克公园'},
#  '六道口': {'北沙滩', '清华东路西口'},
#  '清华东路西口': {'六道口'},
#  '农大南路': {'西苑', '马连洼'},
#  '马连洼': {'农大南路', '西北旺'},
#  '西北旺': {'永丰南', '马连洼'},
#  '永丰南': {'永丰', '西北旺'},
#  '永丰': {'屯佃', '永丰南'},
#  '屯佃': {'永丰', '稻香湖路'},
#  '稻香湖路': {'屯佃', '温阳路'},
#  '温阳路': {'北安河', '稻香湖路'},
#  '北安河': {'温阳路'},
#  '高碑店': {'传媒大学', '四惠东'},
#  '传媒大学': {'双桥', '高碑店'},
#  '双桥': {'传媒大学', '管庄'},
#  '管庄': {'八里桥', '双桥'},
#  '八里桥': {'管庄', '通州北苑'},
#  '通州北苑': {'八里桥', '果园'},
#  '果园': {'九棵树', '通州北苑'},
#  '九棵树': {'果园', '梨园'},
#  '梨园': {'临河里', '九棵树'},
#  '临河里': {'土桥', '梨园'},
#  '土桥': {'临河里'},
#  '昌平西山口': {'十三陵景区'},
#  '十三陵景区': {'昌平', '昌平西山口'},
#  '昌平': {'十三陵景区', '昌平东关'},
#  '昌平东关': {'北邵洼', '昌平'},
#  '北邵洼': {'南邵', '昌平东关'},
#  '南邵': {'北邵洼', '沙河高教园'},
#  '沙河高教园': {'南邵', '沙河'},
#  '沙河': {'巩华城', '沙河高教园'},
#  '巩华城': {'朱辛庄', '沙河'},
#  '生命科学园': {'朱辛庄', '西二旗'},
#  '肖村': {'宋家庄', '小红门'},
#  '小红门': {'旧宫', '肖村'},
#  '旧宫': {'亦庄桥', '小红门'},
#  '亦庄桥': {'亦庄文化园', '旧宫'},
#  '亦庄文化园': {'万源街', '亦庄桥'},
#  '万源街': {'亦庄文化园', '荣京东街'},
#  '荣京东街': {'万源街', '荣昌东街'},
#  '荣昌东街': {'同济南路', '荣京东街'},
#  '同济南路': {'经海路', '荣昌东街'},
#  '经海路': {'同济南路', '次渠南'},
#  '次渠南': {'次渠', '经海路'},
#  '次渠': {'亦庄火车站', '次渠南'},
#  '亦庄火车站': {'次渠'},
#  '大葆台': {'稻田', '郭公庄'},
#  '稻田': {'大葆台', '长阳'},
#  '长阳': {'稻田', '篱笆房'},
#  '篱笆房': {'广阳城', '长阳'},
#  '广阳城': {'篱笆房', '良乡大学城北'},
#  '良乡大学城北': {'广阳城', '良乡大学城'},
#  '良乡大学城': {'良乡大学城北', '良乡大学城西'},
#  '良乡大学城西': {'良乡南关', '良乡大学城'},
#  '良乡南关': {'良乡大学城西', '苏庄'},
#  '苏庄': {'良乡南关', '阎村东'},
#  '阎村东': {'紫草坞', '苏庄'},
#  '四道桥': {'桥户营', '金安桥'},
#  '桥户营': {'上岸', '四道桥'},
#  '上岸': {'栗园庄', '桥户营'},
#  '栗园庄': {'上岸', '小园'},
#  '小园': {'栗园庄', '石厂'},
#  '石厂': {'小园'},
#  '紫草坞': {'阎村', '阎村东'},
#  '阎村': {'星城', '紫草坞'},
#  '星城': {'大石河东', '阎村'},
#  '大石河东': {'星城', '马各庄'},
#  '马各庄': {'大石河东', '饶乐府'},
#  '饶乐府': {'房山城关', '马各庄'},
#  '房山城关': {'燕山', '饶乐府'},
#  '燕山': {'房山城关'},
#  '陶然桥': {'北京南站', '永定门外'},
#  '南八里庄': {'北工大西门', '十里河'},
#  '红庙': {'大望路', '金台路'},
#  '高家园': {'将台', '望京南'},
#  'T3航站楼': {'T2航站楼', '三元桥'},
#  'T2航站楼': {'T3航站楼', '三元桥'}}

# %%
for k, v in connection_map.items():
    if k not in location_map:
        print(k, v)

# %%
location_map['公主坟']
# Out:
# (582.0, 783.0)

# %%
location_map['军事博物馆']
# Out:
# (621.0, 783.0)

# %% [markdown]
# ##### 2.	Preprocessing data from page source.
#
# > a.	Based on the page source gotten from url. You may need some more preprocessing of the page.
#
# > b.	the Regular Expression you may need to process the text information.
#
# > c.	You may need @package networkx, @package matplotlib to visualize data.
#
# > d.	You should build a dictionary or graph which could represent the connection information of Beijing subway routes.
#
# > e.	You may need the defaultdict, set data structures to implement this procedure.

# %%
import networkx as nx

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
# 绘制站点连接图
G = nx.Graph(connection_map)
plt.figure(figsize=(30,30))
ax = plt.gca()                       #获取到当前坐标轴信息
ax.xaxis.set_ticks_position('top')   #将X坐标轴移到上面
ax.invert_yaxis()                    #反转Y坐标轴
nx.draw(G,pos = location_map,with_labels=True,font_size=16, node_size=30,node_color = 'r')

# %%
import math

# %% [markdown]
# ##### 3. Build the search agent
#
# > Build the search agent based on the graph we build.
#
# for example, when you run:
#
# ```python
# >>> search('奥体中心', '天安门')
# ```
# you need get the result:
#
# 奥体中心-> A -> B -> C -> ... -> 天安门

# %%
def search(start, destination, connection_grpah, sort_candidate):
    """
    广度优先搜索，获取最优路径
    """
    pathes = [[start]]
    visitied = set()
    while pathes: 
        path = pathes.pop(0)
        froninter = path[-1]     
        if froninter in visitied: continue          
        successors = connection_grpah[froninter]       
        for city in successors:
            if city in path: continue  
            new_path = path + [city]        
            pathes.append(new_path)
            if city == destination: return new_path
        visitied.add(froninter)
        pathes = sort_candidate(pathes)

# %%
def transfer_stations_first(pathes): 
    """
    最少换乘优先
    """
    return sorted(pathes, key=len)

# %%
# 计算平均时间
diff_time_list = [c.diff_time for c in p2p_map.values() if c.diff_time]
avg_diff_time = round(sum(diff_time_list) / len(diff_time_list), 0)
def transfer_time_fisrt(pathes):
    """
    最短时间优先
    """
    if len(pathes) <= 1:
        return pathes

    def sum_time(path):
        time = 0
        for i in range(len(path) - 1):
            conn = get_connection(path[i], path[i + 1])
            if conn.diff_time:
                time += conn.diff_time
            else:
                time += avg_diff_time  # 没有时间则使用平均时间
        return time

    return sorted(pathes, key=sum_time)

# %%
# 计算平均距离
distance_list = [c.distance for c in p2p_map.values() if c.distance]
avg_distance = round(sum(distance_list) / len(distance_list), 0)
def transfer_distance_fisrt(pathes):
    """
    最短距离优先
    """
    if len(pathes) <= 1:
        return pathes

    def sum_distance(path):
        distance = 0
        for i in range(len(path) - 1):
            conn = get_connection(path[i], path[i + 1])
            if conn.distance:
                distance += conn.distance
            else:
                distance += avg_distance  # 没有距离则使用平均距离
        return distance

    return sorted(pathes, key=sum_distance)

# %%
search('西直门', '国贸', connection_map, sort_candidate=transfer_stations_first)
# Out:
# ['西直门', '新街口', '平安里', '北海北', '南锣鼓巷', '东四', '朝阳门', '建国门', '永安里', '国贸']

# %%
search('西直门', '国贸', connection_map, sort_candidate=transfer_time_fisrt)
# Out:
# ['西直门', '新街口', '平安里', '北海北', '南锣鼓巷', '东四', '朝阳门', '建国门', '永安里', '国贸']

# %%
search('西直门', '国贸', connection_map, sort_candidate=transfer_distance_fisrt)
# Out:
# ['西直门', '新街口', '平安里', '北海北', '南锣鼓巷', '东四', '灯市口', '东单', '建国门', '永安里', '国贸']

# %% [markdown]
# ## （Optional）Create different policies for transfer system.

# %% [markdown]
# 以下部门为可选部分，请酌情完成。 并不要求全部同学完成。

# %% [markdown]
# As much as you can to use the already implemented search agent. You just need to define the **is_goal()**, **get_successor()**, **strategy()** three functions.
#
# > a.	Define different policies for transfer system.
#
# > b.	Such as Shortest Path Priority（路程最短优先）, Minimum Transfer Priority(最少换乘优先), Comprehensive Priority(综合优先)
#
# > c.	Implement Continuous transfer. Based on the Agent you implemented, please add this feature: Besides the @param start and @param destination two stations, add some more stations, we called @param by_way, it means, our path should from the start and end, but also include the  @param by_way stations.
#
# e.g
# ```
# 1. Input:  start=A,  destination=B, by_way=[C]
#     Output: [A, … .., C, …. B]
# 2. Input: start=A, destination=B, by_way=[C, D, E]
#     Output: [A … C … E … D … B]
#     # based on your policy, the E station could be reached firstly.
# ![image.png](attachment:image.png)
# ```

# %% [markdown]
# ##### 5.	Test your result with commercial applications.
#
# 将你的结果和高德地图或者百度地图进行比较，如果有不同，请分析原因

# %% [markdown]
# 恭喜，完成本次课程，你对常用的人工智能方法以及有一定的了解了。基于规则的，基于概率模型的，基于搜索的，基于机器学习的。 可以说，我们现在通常见到的方法都能够归属到这几类方法中。 这就是**人工智能**，并没有很难是吧？ 继续加油！

# %% [markdown]
# ![](https://timgsa.baidu.com/timg?image&quality=80&size=b9999_10000&sec=1562415163815&di=4b29a2a863a8285212033760f288ed7a&imgtype=0&src=http%3A%2F%2F5b0988e595225.cdn.sohucs.com%2Fimages%2F20180710%2F8704194a1d7f46a383ddc29d40c9bca5.jpeg)
